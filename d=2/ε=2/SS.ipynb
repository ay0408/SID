# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
def SS1(eps,beta):
    k = 2-(6*beta*2)/eps
    alpha = (eps/(2*(3**(3/4))))*k
    return (1/(alpha*(2**(1/2))))*2

def SS2(eps,beta):
    k = 2-(6*beta*2)/eps
    alpha = (eps/4)*k
    return ((1/alpha)*(2/(math.pi)))*2

def SS3(eps,beta):
    k = 2-(10*beta*2)/eps
    alpha = (eps/(2*(5**(5/6))))*k
    return (1/(alpha*(3**(1/2))))*2

# %%
beta = [0.08*i for i in range(9)]

eps = 2
for i in range(5):
    print(SS1(eps,beta[i]))
# Out:
# 1.6118548977353127
# 2.1208617075464637
# 3.099720957183293
# 5.756624634768974
# 40.29637244338278

# %%
for i in range(5):
    print(SS2(eps,beta[i]))
# Out:
# 1.2732395447351628
# 1.6753151904410037
# 2.448537586029159
# 4.547284088339866
# 31.830988618379042

# %%
for i in range(3):
    print(SS3(eps,beta[i]))
# Out:
# 2.20756945463137
# 3.679282424385617
# 11.037847273156853
