# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
def SS1(eps,beta):
    k = 2-(6*beta*2)/eps
    alpha = (eps/(2*(3**(3/4))))*k
    return (1/(alpha*(2**(1/2))))*2

def SS2(eps,beta):
    k = 2-(6*beta*2)/eps
    alpha = (eps/4)*k
    return ((1/alpha)*(2/(math.pi)))*2

def SS3(eps,beta):
    k = 2-(10*beta*2)/eps
    alpha = (eps/(2*(5**(5/6))))*k
    return (1/(alpha*(3**(1/2))))*2

# %%
beta = [0.4*i for i in range(9)]

eps = 10
for i in range(5):
    print(SS1(eps,beta[i]))
# Out:
# 0.3223709795470625
# 0.4241723415092928
# 0.6199441914366588
# 1.151324926953795
# 8.0592744886766

# %%
for i in range(5):
    print(SS2(eps,beta[i]))
# Out:
# 0.25464790894703254
# 0.3350630380882007
# 0.48970751720583194
# 0.9094568176679737
# 6.366197723675843

# %%
for i in range(3):
    print(SS3(eps,beta[i]))
# Out:
# 0.441513890926274
# 0.7358564848771233
# 2.20756945463137
