# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
def SS1(eps,beta):
    k = 2-(6*beta*2)/eps
    alpha = (eps/(2*(3**(3/4))))*k
    return (1/(alpha*(2**(1/2))))*2

def SS2(eps,beta):
    k = 2-(6*beta*2)/eps
    alpha = (eps/4)*k
    return ((1/alpha)*(2/(math.pi)))*2

def SS3(eps,beta):
    k = 2-(10*beta*2)/eps
    alpha = (eps/(2*(5**(5/6))))*k
    return (1/(alpha*(3**(1/2))))*2

# %%
beta = [0.2*i for i in range(9)]

eps = 5
for i in range(5):
    print(SS1(eps,beta[i]))
# Out:
# 0.644741959094125
# 0.8483446830185856
# 1.2398883828733176
# 2.30264985390759
# 16.1185489773532

# %%
for i in range(5):
    print(SS2(eps,beta[i]))
# Out:
# 0.5092958178940651
# 0.6701260761764014
# 0.9794150344116639
# 1.8189136353359474
# 12.732395447351687

# %%
for i in range(3):
    print(SS3(eps,beta[i]))
# Out:
# 0.883027781852548
# 1.4717129697542466
# 4.41513890926274
