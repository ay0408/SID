# %%
from sympy import *
from scipy.optimize import minimize
from scipy import integrate
from scipy.integrate import quad
from mpmath import nsum, inf

# %%
def E(peps,beta,r): #beta > 0
    g = lambda z1, z2, k: -((exp(peps)-1)/(exp(peps+beta*r)))*(((z1+z2-((exp(beta)/(exp(beta)-1))*(exp(beta*k)-1)))/exp(beta*k))**r)+1

    m = lambda k: (1/exp(peps*k))*quad(lambda z1: quad(lambda z2: g(z1,z2,k), max(0,((exp(beta)/(exp(beta)-1))*(exp(beta*k)-1))-z1), ((exp(beta)/(exp(beta)-1))*(exp(beta*(k+1))-1))-z1)[0], 0, ((exp(beta)/(exp(beta)-1))*(exp(beta*(k+1))-1)))[0]
    M = nsum(lambda k: m(k), [0,inf])
    #print(M)

    c = lambda k: (1/exp(peps*k))*quad(lambda z1: quad(lambda z2: (z1+z2)*g(z1,z2,k), max(0,((exp(beta)/(exp(beta)-1))*(exp(beta*k)-1))-z1), ((exp(beta)/(exp(beta)-1))*(exp(beta*(k+1))-1))-z1)[0], 0, ((exp(beta)/(exp(beta)-1))*(exp(beta*(k+1))-1)))[0]
    C = nsum(lambda k: c(k), [0,inf])
    #print(C)
    
    return C/M

def E2(peps,beta,r): #beta = 0
    g = lambda z1, z2, k: -((exp(peps)-1)/(exp(peps+beta*r)))*(((z1+z2-k)/exp(beta*k))**r)+1

    m = lambda k: (1/exp(peps*k))*quad(lambda z1: quad(lambda z2: g(z1,z2,k), max(0,k-z1), k+1-z1)[0], 0, k+1)[0]
    M = nsum(lambda k: m(k), [0,inf])
    #print(M)

    c = lambda k: (1/exp(peps*k))*quad(lambda z1: quad(lambda z2: (z1+z2)*g(z1,z2,k), max(0,k-z1), k+1-z1)[0], 0, k+1)[0]
    C = nsum(lambda k: c(k), [0,inf])
    #print(C)
    
    return C/M

def S(peps,beta,r):
    return peps+log(1-((exp(peps)-1)/exp(peps+r*beta))*((exp(beta)-1)**r))

# %%
eps = 5; beta = 1.6
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((3*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta*2-S(x[0],beta,x[1])},)
res = minimize(fun, (eps,0.2), bounds = bnds, constraints = cons)
print(res.fun, res.x)
# Out:
# /var/folders/b7/k97h61fx3kzgv6d0m1d0f3tc0000gn/T/ipykernel_72732/2563342340.py:8: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   c = lambda k: (1/exp(peps*k))*quad(lambda z1: quad(lambda z2: (z1+z2)*g(z1,z2,k), max(0,((exp(beta)/(exp(beta)-1))*(exp(beta*k)-1))-z1), ((exp(beta)/(exp(beta)-1))*(exp(beta*(k+1))-1))-z1)[0], 0, ((exp(beta)/(exp(beta)-1))*(exp(beta*(k+1))-1)))[0]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       5 bnds = ((3*beta,eps), (0,None))
#       6 cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta*2-S(x[0],beta,x[1])},)
# ----> 7 res = minimize(fun, (eps,0.2), bounds = bnds, constraints = cons)
#       8 print(res.fun, res.x)
#
# File /opt/anaconda3/lib/python3.12/site-packages/scipy/optimize/_minimize.py:722, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     719     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     720                            bounds=bounds, **options)
#     721 elif meth == 'slsqp':
# --> 722     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     723                           constraints, callback=callback, **options)
#     724 elif meth == 'trust-constr':
#     725     res = _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#     726                                        bounds, constraints,
#     727                                        callback=callback, **options)
#
# File /opt/anaconda3/lib/python3.12/site-packages/scipy/optimize/_slsqp_py.py:383, in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, finite_diff_rel_step, **unknown_options)
#     380     xu[infbnd[:, 1]] = np.nan
#     382 # ScalarFunction provides function and gradient evaluation
# --> 383 sf = _prepare_scalar_function(func, x, jac=jac, args=args, epsilon=eps,
#     384                               finite_diff_rel_step=finite_diff_rel_step,
#     385                               bounds=new_bounds)
#     386 # gh11403 SLSQP sometimes exceeds bounds by 1 or 2 ULP, make sure this
#     387 # doesn't get sent to the func/grad evaluator.
#     388 wrapped_fun = _clip_x_for_func(sf.fun, new_bounds)
#
# File /opt/anaconda3/lib/python3.12/site-packages/scipy/optimize/_optimize.py:288, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     284     bounds = (-np.inf, np.inf)
#     286 # ScalarFunction caches. Reuse of fun(x) during grad
#     287 # calculation reduces overall function evaluations.
# --> 288 sf = ScalarFunction(fun, x0, args, grad, hess,
#     289                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     291 return sf
#
# File /opt/anaconda3/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:166, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     163     self.f = fun_wrapped(self.x)
#     165 self._update_fun_impl = update_fun
# --> 166 self._update_fun()
#     168 # Gradient evaluation
#     169 if callable(grad):
#
# File /opt/anaconda3/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:262, in ScalarFunction._update_fun(self)
#     260 def _update_fun(self):
#     261     if not self.f_updated:
# --> 262         self._update_fun_impl()
#     263         self.f_updated = True
#
# File /opt/anaconda3/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:163, in ScalarFunction.__init__.<locals>.update_fun()
#     162 def update_fun():
# --> 163     self.f = fun_wrapped(self.x)
#
# File /opt/anaconda3/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# Cell In[3], line 4, in <lambda>(x)
#       1 eps = 5; beta = 1.6
#       2 #peps = x[0], r = x[1]
# ----> 4 fun = lambda x: E(x[0],beta,x[1])
#       5 bnds = ((3*beta,eps), (0,None))
#       6 cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta*2-S(x[0],beta,x[1])},)
#
# Cell In[2], line 9, in E(peps, beta, r)
#       6 #print(M)
#       8 c = lambda k: (1/exp(peps*k))*quad(lambda z1: quad(lambda z2: (z1+z2)*g(z1,z2,k), max(0,((exp(beta)/(exp(beta)-1))*(exp(beta*k)-1))-z1), ((exp(beta)/(exp(beta)-1))*(exp(beta*(k+1))-1))-z1)[0], 0, ((exp(beta)/(exp(beta)-1))*(exp(beta*(k+1))-1)))[0]
# ----> 9 C = nsum(lambda k: c(k), [0,inf])
#      10 #print(C)
#      12 return C/M
#
# File /opt/anaconda3/lib/python3.12/site-packages/mpmath/calculus/extrapolation.py:1718, in nsum(ctx, f, *intervals, **options)
#    1715     ctx.prec = workprec
#    1716     return v
# -> 1718 return +ctx.adaptive_extrapolation(update, emfun, options)
#
# File /opt/anaconda3/lib/python3.12/site-packages/mpmath/calculus/extrapolation.py:1173, in adaptive_extrapolation(ctx, update, emfun, kwargs)
#    1171 if verbose:
#    1172     print("Direct error: %s" % ctx.nstr(error))
# -> 1173 if error <= tol:
#    1174     return best
#    1176 # Check each extrapolation method
#
# File /opt/anaconda3/lib/python3.12/site-packages/sympy/core/decorators.py:236, in _SympifyWrapper.make_wrapped.<locals>._func(self, other)
#     234 if not isinstance(other, expectedcls):
#     235     return retval
# --> 236 return func(self, other)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sympy/core/expr.py:355, in Expr.__le__(self, other)
#     352 @sympify_return([('other', 'Expr')], NotImplemented)
#     353 def __le__(self, other):
#     354     from .relational import LessThan
# --> 355     return LessThan(self, other)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sympy/core/relational.py:843, in _Inequality.__new__(cls, lhs, rhs, **options)
#     841         raise TypeError("Invalid comparison of non-real %s" % me)
#     842     if me is S.NaN:
# --> 843         raise TypeError("Invalid NaN comparison")
#     844 # First we invoke the appropriate inequality method of `lhs`
#     845 # (e.g., `lhs.__lt__`).  That method will try to reduce to
#     846 # boolean or raise an exception.  It may keep calling
#    (...)
#     850 # exception).  In that case, it must call us with
#     851 # `evaluate=False` to prevent infinite recursion.
#     852 return cls._eval_relation(lhs, rhs, **options)
#
# TypeError: Invalid NaN comparison
