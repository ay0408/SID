# %%
from sympy import *
from scipy.optimize import minimize
from scipy import integrate
from scipy.integrate import quad
import matplotlib.pyplot as plt
import numpy as np
import math
import random
from mpmath import nsum, inf

# %%
#beta = 0
def g(z):
    return -((math.exp(5)-1)/(math.exp(5)*math.log(2)))*math.log(abs(z)**0.30904249+1)+1

def b(k):
    return k

def X(k):
    return quad(lambda z1: quad(lambda z2: g(z1+z2-b(k)), max(0,b(k)-z1), b(k+1)-z1)[0], 0, b(k+1))[0]

def S(a,k):
    T = nsum(lambda i: (1/math.exp(5*i))*X(i), [0,k-1])
    return a*T

def ComputeZ(a,d):
    c = random.uniform(0,1/(2**d))
    #print(c)
    k = 0
    while(1):
        if S(a,k) <= math.fabs(c) and math.fabs(c) < S(a,k+1):
            break
        else:
            k += 1
    #print(math.fabs(c)-S(a,k))
    fun = lambda x: math.fabs(math.fabs(c)-S(a,k)-a*(1/math.exp(5*k))*quad(lambda z1: quad(lambda z2: g(z1+z2-b(k)), max(0,b(k)-z1), b(k)+x[0]-z1)[0], 0, b(k)+x[0])[0])
    bnds = ((0,1), (0,None))
    res = minimize(fun, (0.1,1), bounds = bnds)
    #print(res.fun, res.x)
    return b(k)+res.x[0] #||Z||_1

# %%
def Evaluation(a,d):
    Z = 0
    for i in range(100):
        Z += ComputeZ(a,d)
    return Z/100

# %%
a = 1/(4*nsum(lambda k: (1/math.exp(5*k))*X(k), [0,inf]))
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(a,2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 0.47714838878721094
# 0.4718666650179076
# 0.45595989419347416
# 0.5106946436400209
# 0.49461192550742467
# 0.5514999580311544
# 0.5000365045735581
# 0.4962067131698771
# 0.5185745603163618
# 0.4562482709569602
# 0.4693975722979929
# 0.4899462281639213
# 0.48413184829321154
# 0.5062206225836267
# 0.5368363046490898
# 0.47894795095484555
# 0.4966379098080671
# 0.481678260275638
# 0.515836320193953
# 0.5637107172849487
# 0.45453717932755516
# 0.505818664657505
# 0.5050492798088042
# 0.5000483390697058
# 0.5327242720719629
# 0.505493289290989
# 0.4677633105128822
# 0.501547704450044
# 0.47275694727354867
# 0.512326015169219
# 0.4841739293169007
# 0.5004268914814352
# 0.5035152580106792
# 0.4863799388740123
# 0.5081625256190843
# 0.48081887929281114
# 0.47349624757524084
# 0.4916237683908471
# 0.483614753408378
# 0.5211549906925278
# 0.4984345023084279
# 0.5192138321445636
# 0.5317999368972308
# 0.4594657919051426
# 0.5143678866753281
# 0.4926094039519655
# 0.4815237961642669
# 0.49992041831210565
# 0.5022678613848326
# 0.4600643947558406
# 0.46389576287158235
# 0.48084350042978125
# 0.510475050900368
# 0.4926972457312516
# 0.5138514280270869
# 0.48197816726747367
# 0.5031380768092618
# 0.49474260212645993
# 0.45651950203500674
# 0.4959570714270363
# 0.4983581197217848
# 0.48279657791441205
# 0.47826592380819355
# 0.4817798166548707
# 0.4769936701485672
# 0.4912174298444668
# 0.4924702196837319
# 0.4867086424604411
# 0.5065075428525396
# 0.5545729627877966
# 0.45611825963633423
# 0.503825305257044
# 0.5002004266376319
# 0.5158116529808887
# 0.5068993366336295
# 0.4788783114521369
# 0.5072935096420048
# 0.4933085767819507
# 0.5101378029645246
# 0.4944124372044804
# 0.5039362701269916
# 0.5349446992909213
# 0.540720824791565
# 0.5322149263281001
# 0.4313146899055073
# 0.5009541511652441
# 0.6071088323710612
# 0.49266127398116283
# 0.516669856168781
# 0.5277485511091228
# 0.5292769706052607
# 0.5285868727716653
# 0.48974276991210547
# 0.5550087082592466
# 0.44556203500549174
# 0.4869805767775066
# 0.4501750944478424
# 0.528226788972932
# 0.5049059757808688
# 0.4927513052539564
# -----
# 0.4981743737321115
# 0.6071088323710612 0.4313146899055073

# %%
beta = 0.2; peps = 5; r = 0.32068899
def g(z):
    return -((math.exp(peps)-1)/(math.exp(peps)*math.log(math.exp(beta*r)+1)))*math.log(abs(z)**r+1)+1

def b(k):
    return (math.exp(beta)/(math.exp(beta)-1))*(math.exp(beta*k)-1)

def X(k):
    return quad(lambda z1: quad(lambda z2: g((z1+z2-b(k))/math.exp(beta*k)), max(0,b(k)-z1), b(k+1)-z1)[0], 0, b(k+1))[0]

def S(a,k):
    T = nsum(lambda i: (1/math.exp(peps*i))*X(i), [0,k-1])
    return a*T

def ComputeZ(a,d):
    c = random.uniform(0,1/(2**d))
    #print(c)
    k = 0
    while(1):
        if S(a,k) <= math.fabs(c) and math.fabs(c) < S(a,k+1):
            break
        else:
            k += 1
    #print(math.fabs(c)-S(a,k))
    fun = lambda x: math.fabs(math.fabs(c)-S(a,k)-a*(1/math.exp(peps*k))*quad(lambda z1: quad(lambda z2: g((z1+z2-b(k))/math.exp(beta*k)), max(0,b(k)-z1), b(k)+x[0]-z1)[0], 0, b(k)+x[0])[0])
    bnds = ((0,math.exp(beta*(k+1))), (0,None))
    res = minimize(fun, (0.1,1), bounds = bnds)
    #print(res.fun, res.x)
    return b(k)+res.x[0] #||Z||_1

# %%
a = 1/(4*nsum(lambda k: (1/math.exp(peps*k))*X(k), [0,inf]))
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(a,2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 0.6061600695996742
# 0.5800745391734143
# 0.6470727287903186
# 0.6040008546772141
# 0.5957015868142506
# 0.6552025958849922
# 0.5685161312998422
# 0.6672755892875134
# 0.5933739110440799
# 0.6647121237069803
# 0.6215030235653706
# 0.5412193061322277
# 0.593673129219971
# 0.5593375704403134
# 0.6239810849755075
# 0.6224186129631414
# 0.6405168937857565
# 0.653872681416262
# 0.645126055988788
# 0.6094885773579096
# 0.6698197045128091
# 0.6286328189979884
# 0.6073977322902959
# 0.5965428700435469
# 0.6128133750610354
# 0.6981379565220429
# 0.6579879278190753
# 0.6328086140185162
# 0.59012174884199
# 0.675296184663181
# 0.6407258604333463
# 0.6792856761783871
# 0.6205746548790448
# 0.5879358652596761
# 0.6547615978343897
# 0.6772095888475156
# 0.573025933790314
# 0.6169529502570374
# 0.639979032893683
# 0.5441950277936192
# 0.6275352438902251
# 0.5766207321404807
# 0.5990168010451827
# 0.6229371379816014
# 0.6290893360541356
# 0.628375999696278
# 0.6652020028787075
# 0.6135217496447388
# 0.6643817381257635
# 0.5894055787620734
# 0.6187682348421188
# 0.5817550517800602
# 0.612926393165002
# 0.6546227821196696
# 0.6246463089907037
# 0.615427804390628
# 0.6279584900746875
# 0.6054829337928089
# 0.6645756638076687
# 0.6168819014969398
# 0.6300463018675293
# 0.5753883810922633
# 0.6616511464955473
# 0.5927712229605769
# 0.6012308237330365
# 0.5692008598746521
# 0.5844929087308767
# 0.6564273023057584
# 0.6356094096120825
# 0.5496340349769857
# 0.69276330735983
# 0.6055712065148061
# 0.6308185338452332
# 0.6243272151612425
# 0.6551376954547891
# 0.637378378323222
# 0.673287997862579
# 0.6848970812067597
# 0.6170941560356497
# 0.6020604259855372
# 0.6611771961867197
# 0.5645895601767253
# 0.5700814347210988
# 0.6271925222973228
# 0.6289827031219082
# 0.6140440048938128
# 0.6139126532327552
# 0.5778244023329617
# 0.6413138293096927
# 0.6016726691998052
# 0.5627890086750483
# 0.6346067400812032
# 0.6412022946842544
# 0.6129165817673632
# 0.6221921066529985
# 0.5836596349111094
# 0.5266189894507814
# 0.6146624689862105
# 0.5658396727344447
# 0.6165596518022739
# -----
# 0.6189819058635795
# 0.6981379565220429 0.5266189894507814

# %%
beta = 0.4; peps = 5; r = 0.33338787
a = 1/(4*nsum(lambda k: (1/math.exp(peps*k))*X(k), [0,inf]))
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(a,2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 0.6890077072979787
# 0.7693946209581566
# 0.8255900381495634
# 0.8161914486690338
# 0.8886316844183528
# 0.7929079140116593
# 0.780228935133972
# 0.8109019604545664
# 0.790735409527936
# 0.7788434062733418
# 0.7618170255339847
# 0.7210854536912152
# 0.7476516065007296
# 0.7287991165990576
# 0.7320589245894817
# 0.7365521376116603
# 0.8039171325892164
# 0.6681639417991563
# 0.8059471760151935
# 0.7990477304485776
# 0.8864755563069618
# 0.7674067340792402
# 0.7879826458781432
# 0.7584107093862253
# 0.7338103465457831
# 0.7616930487593474
# 0.7828153735955364
# 0.7986095769416184
# 0.7846901694167744
# 0.6975937964896322
# 0.7864334692456718
# 0.9190776139493008
# 0.7206977629131502
# 0.7627134733628451
# 0.7490396370746916
# 0.7557069391255498
# 0.7428832998811273
# 0.8230146465506014
# 0.7401568957534009
# 0.7129789601369204
# 0.7685598623911521
# 0.7465555247262426
# 0.7388604474916943
# 0.7304298404652699
# 0.7338356107732897
# 0.6976373149624285
# 0.7833985876585756
# 0.7792449054767965
# 0.8370181056650255
# 0.7888913986982713
# 0.7600819362841154
# 0.686054650154185
# 0.7004374271140855
# 0.7457239062615786
# 0.7905819181947977
# 0.7271346002159425
# 0.8046388005441313
# 0.7411204697783182
# 0.7562543434365122
# 0.8861602878445816
# 0.7440313074700683
# 0.814627244722452
# 0.7924086715598294
# 0.8018029011275268
# 0.7124981054840854
# 0.8195056933950441
# 0.6749265512273738
# 0.7831183148381371
# 0.8204695592055019
# 0.8470647545383966
# 0.7663129271399787
# 0.7928202637549359
# 0.7747736134878292
# 0.8180691301714985
# 0.7346151013592985
# 0.8384227196826523
# 0.8371992306919381
# 0.8236601998517523
# 0.7654438999274389
# 0.8007796637015311
# 0.7678797335059612
# 0.7688523632362684
# 0.698289712497838
# 0.7707179976904192
# 0.7308661602117994
# 0.7622381378387806
# 0.7827330607388848
# 0.8000219287556721
# 0.795572742450915
# 0.7880378020943988
# 0.8233656389246131
# 0.7926184023570737
# 0.7659164970837409
# 0.7983744198373195
# 0.7942723553328572
# 0.8215811493346149
# 0.761806855351752
# 0.7307448832478265
# 0.8268197745837031
# 0.7188466099281079
# -----
# 0.7738439004214215
# 0.9190776139493008 0.6681639417991563

# %%
beta = 0.6; peps = 5; r = 0.34606678
a = 1/(4*nsum(lambda k: (1/math.exp(peps*k))*X(k), [0,inf]))
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(a,2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 1.0366988284326546
# 1.0303063152875782
# 1.0220632607065578
# 0.9369591419416846
# 0.9840630085149145
# 0.9869200861732199
# 0.9959203951047467
# 0.9416393307348829
# 1.0123601831496647
# 0.9668727541283942
# 0.9988149042810073
# 0.944424908574768
# 0.9725892219476501
# 0.9730918914609755
# 0.9285316881639624
# 1.0128709201263697
# 0.9707438983970763
# 0.8315261768067408
# 1.0573217110498683
# 0.9690913164421175
# 0.9196702376614836
# 1.0427249999540242
# 0.942601360316159
# 1.0564397868075968
# 1.1669319749147988
# 1.1125001487135933
# 0.9644420877995573
# 1.0804933701964388
# 1.0467092999565177
# 0.9676800298167578
# 1.0929106620360516
# 1.0528661040433347
# 0.9830613835840029
# 1.0663909591431473
# 1.059539713344882
# 0.9520901682473364
# 1.0358653229356138
# 0.9780606367323403
# 1.0330507353251326
# 0.8822397402311306
# 0.9450746202093044
# 0.885331123230371
# 0.9241639948097307
# 0.9377194894281202
# 0.9060389340962136
# 1.0069206528282226
# 1.0369549315981765
# 1.010601767359559
# 0.9186787492155024
# 0.9360144485078722
# 0.9593313069107122
# 1.0018448942960614
# 1.0675016687816705
# 0.9459481164729567
# 1.0458821042365205
# 0.891953798680096
# 0.9199126197021533
# 1.05797500672356
# 1.028942942589673
# 0.8704450625991502
# 0.9307191058180346
# 0.9902185942840367
# 1.0610481955581244
# 1.0572761104824657
# 0.9074053940554346
# 1.0937547153093543
# 1.0193647671868484
# 0.994394932645412
# 0.9686646050342822
# 1.0558862451845545
# 1.1179884864555927
# 0.8745285452935964
# 0.8474567288994376
# 0.9625393821953477
# 1.011821418549021
# 1.0418162944433311
# 0.9716631839494405
# 0.8524282147173662
# 1.0948195616210703
# 0.9404206494494788
# 1.1405401355619325
# 1.049334728598402
# 0.935795475739785
# 0.9170182580092617
# 0.9387792718410514
# 1.00698905940704
# 1.0004543705652604
# 0.9260923265210849
# 0.8703896540756151
# 0.8962472738005856
# 1.006074856716991
# 0.8607142213791437
# 1.024490871227262
# 0.890363142305893
# 0.9694092716444699
# 0.9610399981005969
# 1.0022723019746749
# 1.035301946899819
# 0.9197199902025449
# 0.950948594751801
# -----
# 0.9840250577591578
# 1.1669319749147988 0.8315261768067408

# %%
beta = 0.8; peps = 5; r = 0.36415074
a = 1/(4*nsum(lambda k: (1/math.exp(peps*k))*X(k), [0,inf]))
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(a,2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 1.2748613302608403
# 1.3836137653475893
# 1.3188146314805849
# 1.366225158855829
# 1.314333111475651
# 1.2185237230205042
# 1.3791752365991548
# 1.3826721631215972
# 1.2615832695332485
# 1.53749952070235
# 1.2746847092437943
# 1.219436266058674
# 1.192993530085627
# 1.2566274287787162
# 1.3497057962785362
# 1.1410642430150653
# 1.3508009628640558
# 1.3112701649090948
# 1.221617817449817
# 1.2359691530606118
# 1.0720798896703452
# 1.319845355216119
# 1.212200463316122
# 1.4177253784315818
# 1.2747986032085614
# 1.4508004599029776
# 1.1912459861371385
# 1.478792081117572
# 1.5958226085961797
# 1.2693052279918677
# 1.425218075327009
# 1.3541523199294745
# 1.2852994391149573
# 1.2795906537140238
# 1.3702017820140275
# 1.2512455595861613
# 1.10782922542315
# 1.2840642767566899
# 1.4050632997701982
# 1.1683248722096031
# 1.2291737598396835
# 1.151891466237323
# 1.201962114435548
# 1.255580512459256
# 1.353056153370205
# 1.4183561304067624
# 1.3637978431878701
# 1.3571764150082704
# 1.3711752368377157
# 1.277980725926571
# 1.496869822260534
# 1.210676528800285
# 1.3964882210356564
# 1.092700075803035
# 1.7985261298370432
# 1.1644919460374965
# 1.3650459823646506
# 1.2367477003508132
# 1.1323544805688024
# 1.6338946120901232
# 1.2389385371589237
# 1.152324676027983
# 1.5349733152314906
# 1.4901159808665618
# 1.0344307413366747
# 1.4492360597886655
# 1.3166150149583071
# 1.2479261863122637
# 1.2061915195758608
# 1.368256258095868
# 1.139161456743694
# 1.1530969255406964
# 1.180949834489871
# 1.112140921781262
# 1.14232109389826
# 1.3207618423746208
# 1.191246494157984
# 1.3924881450636502
# 1.4810259235062773
# 1.3082583361333042
# 1.1878840435874563
# 1.2522641495099587
# 1.324020022076024
# 1.6304405007860512
# 1.203488659484698
# 1.4671074095774932
# 1.1580041178762397
# 1.1488872367363157
# 1.3095982369961938
# 1.4864190138803832
# 1.2149351819745062
# 1.4933607335847165
# 1.4240019790335148
# 1.4638309706829933
# 1.4186882951713775
# 1.2601033196620057
# 1.4243995930948885
# 1.250755080133311
# 1.3760948155968473
# 1.0596731387823979
# -----
# 1.3072743915770237
# 1.7985261298370432 1.0344307413366747
