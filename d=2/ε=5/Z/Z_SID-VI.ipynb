# %%
from sympy import *
from scipy.optimize import minimize
from scipy import integrate
from scipy.integrate import quad
import matplotlib.pyplot as plt
import numpy as np
import math
import random
from mpmath import nsum, inf

# %%
#beta = 0
def g(z):
    return 1

def b(k):
    return k

def X(k):
    return quad(lambda z1: quad(lambda z2: g(z1+z2-b(k)), max(0,b(k)-z1), b(k+1)-z1)[0], 0, b(k+1))[0]

def S(a,k):
    T = nsum(lambda i: (1/math.exp(5*i))*X(i), [0,k-1])
    return a*T

def ComputeZ(a,d):
    c = random.uniform(0,1/(2**d))
    #print(c)
    k = 0
    while(1):
        if S(a,k) <= math.fabs(c) and math.fabs(c) < S(a,k+1):
            break
        else:
            k += 1
    #print(math.fabs(c)-S(a,k))
    fun = lambda x: math.fabs(math.fabs(c)-S(a,k)-a*(1/math.exp(5*k))*quad(lambda z1: quad(lambda z2: g(z1+z2-b(k)), max(0,b(k)-z1), b(k)+x[0]-z1)[0], 0, b(k)+x[0])[0])
    bnds = ((0,1), (0,None))
    res = minimize(fun, (0.1,1), bounds = bnds)
    #print(res.fun, res.x)
    return b(k)+res.x[0] #||Z||_1

# %%
def Evaluation(a,d):
    Z = 0
    for i in range(100):
        Z += ComputeZ(a,d)
    return Z/100

# %%
a = 1/(4*nsum(lambda k: (1/math.exp(5*k))*X(k), [0,inf]))
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(a,2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 0.7275874107062402
# 0.6963825141715095
# 0.680974291053597
# 0.6715923426591914
# 0.6933078594623788
# 0.7181881348499405
# 0.6672337985635225
# 0.7288457578966672
# 0.657997784991536
# 0.7073034977297319
# 0.7026398807047258
# 0.6507211041961523
# 0.7387797317134289
# 0.6738258034060216
# 0.6688707088986199
# 0.7106899515354331
# 0.7196763632212203
# 0.7138433192089743
# 0.6385869868206054
# 0.6307870384481645
# 0.6675386273477986
# 0.727450771415301
# 0.6538681337132753
# 0.6929683095330639
# 0.709875085079442
# 0.6903896057511677
# 0.6878993021229408
# 0.7180346773424633
# 0.67488955767406
# 0.6896570511546857
# 0.6744028009565867
# 0.6771077531648199
# 0.6671591041333831
# 0.6907060854867414
# 0.6946463975270848
# 0.6999372213537799
# 0.7200354939849544
# 0.7357592845362578
# 0.7615481346158923
# 0.7253442978569196
# 0.6874652486543887
# 0.6958874711782619
# 0.6721848765904288
# 0.6757863189867165
# 0.7275281211026026
# 0.6822362469405353
# 0.7190739734531028
# 0.6669902729349017
# 0.7369141210009407
# 0.652057778298378
# 0.7149839608271139
# 0.6861416476704406
# 0.6716789565669775
# 0.6849762455488458
# 0.6841110966506426
# 0.6677317128690018
# 0.6997756220467184
# 0.7483924103503885
# 0.687720593093611
# 0.6820612345731232
# 0.6759581579289242
# 0.6456989488101557
# 0.6935435308747384
# 0.6751752930941923
# 0.6534238522095862
# 0.6478833651442814
# 0.6844462722411762
# 0.7025778517840174
# 0.653154563660104
# 0.6795747961791048
# 0.7128870304190323
# 0.6796678121123836
# 0.6859114558940135
# 0.6837279903907101
# 0.655253424193443
# 0.6784091939658697
# 0.6682262472502535
# 0.6957591564690384
# 0.683428794307562
# 0.7027582253521999
# 0.6773767384123899
# 0.6565111232042173
# 0.6898192928294153
# 0.6689205928294965
# 0.7221850825566866
# 0.642675959985721
# 0.7073651726326489
# 0.6893085641942862
# 0.6983178153491765
# 0.6309003473927034
# 0.711516776350816
# 0.6725771614653104
# 0.6747437311668578
# 0.649762950592391
# 0.6635836323924038
# 0.7471428099466066
# 0.6985794016378827
# 0.6613593011111476
# 0.6899699058112582
# 0.6724332777531593
# -----
# 0.6878326548422075
# 0.7615481346158923 0.6307870384481645

# %%
beta = 0.2; peps = 4.6
def g(z):
    return 1

def b(k):
    return (math.exp(beta)/(math.exp(beta)-1))*(math.exp(beta*k)-1)

def X(k):
    return quad(lambda z1: quad(lambda z2: g((z1+z2-b(k))/math.exp(beta*k)), max(0,b(k)-z1), b(k+1)-z1)[0], 0, b(k+1))[0]

def S(a,k):
    T = nsum(lambda i: (1/math.exp(peps*i))*X(i), [0,k-1])
    return a*T

def ComputeZ(a,d):
    c = random.uniform(0,1/(2**d))
    #print(c)
    k = 0
    while(1):
        if S(a,k) <= math.fabs(c) and math.fabs(c) < S(a,k+1):
            break
        else:
            k += 1
    #print(math.fabs(c)-S(a,k))
    fun = lambda x: math.fabs(math.fabs(c)-S(a,k)-a*(1/math.exp(peps*k))*quad(lambda z1: quad(lambda z2: g((z1+z2-b(k))/math.exp(beta*k)), max(0,b(k)-z1), b(k)+x[0]-z1)[0], 0, b(k)+x[0])[0])
    bnds = ((0,math.exp(beta*(k+1))), (0,None))
    res = minimize(fun, (0.1,1), bounds = bnds)
    #print(res.fun, res.x)
    return b(k)+res.x[0] #||Z||_1

# %%
a = 1/(4*nsum(lambda k: (1/math.exp(peps*k))*X(k), [0,inf]))
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(a,2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 0.8805836250491388
# 0.9030255503857519
# 0.886339331762499
# 0.8130483333618227
# 0.8563449626674935
# 0.8671497878043894
# 0.8721591453267858
# 0.7982104598827968
# 0.8435788043673835
# 0.8928140318168662
# 0.886345963203654
# 0.8787953577084185
# 0.8416939175463196
# 0.893519088038977
# 0.8454769072827407
# 0.8788218613564492
# 0.8321076349169934
# 0.8375135997060988
# 0.9011020705401025
# 0.8755228124731614
# 0.8515460253120992
# 0.8146560558904171
# 0.842010824534078
# 0.8837680945275613
# 0.8469020817281776
# 0.8533286811583625
# 0.82556157142871
# 0.8203992277385137
# 0.8253967542022772
# 0.8172298028214512
# 0.8387681262832067
# 0.8555883723311459
# 0.8979788146589952
# 0.792001083554704
# 0.8885003755529844
# 0.8441534568044966
# 0.8448914242685656
# 0.867858423432085
# 0.8373536255758112
# 0.9175806286839174
# 0.866009023929805
# 0.851339161911025
# 0.8576097307052603
# 0.8893158110320001
# 0.8899139240280151
# 0.9098988203388885
# 0.8632761227763853
# 0.8603543197636416
# 0.8418959978617963
# 0.9148731619256398
# 0.8883997337425636
# 0.9329733946784625
# 0.892947879305695
# 0.8626791208753677
# 0.8899555140831794
# 0.8171687191996562
# 0.8519437757234756
# 0.8962037466264416
# 0.8616191312204249
# 0.9587362116613458
# 0.813885044639589
# 0.8971724897421806
# 0.8018729724922761
# 0.8756517265004105
# 0.8767542292898483
# 0.8889034274791101
# 0.889110400859549
# 0.8890413723708037
# 0.8365423803316803
# 0.8429921466961176
# 0.8522246163408853
# 0.9110426020047862
# 0.8101746598627969
# 0.9063034879483547
# 0.9302042754018497
# 0.9144900923536271
# 0.8698848086402751
# 0.8937394953704525
# 0.8504155017495785
# 0.8616836762724948
# 0.8754979693427337
# 0.8836082053817702
# 0.8572149786679176
# 0.8446673948857044
# 0.8458008958884924
# 0.9436076209319925
# 0.8614349291489987
# 0.9036074715900938
# 0.7946668229500554
# 0.8356846844843527
# 0.8811861801964603
# 0.8892517232249914
# 0.8562172282973981
# 0.9354299667929269
# 0.8814253883010431
# 0.8570419725065396
# 0.9555789489295199
# 0.8941541694477221
# 0.8922404046490524
# 0.8831906225579267
# -----
# 0.8683033698159681
# 0.9587362116613458 0.792001083554704

# %%
beta = 0.4; peps = 4.2
a = 1/(4*nsum(lambda k: (1/math.exp(peps*k))*X(k), [0,inf]))
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(a,2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 1.1443215650830327
# 1.1867867133536176
# 1.1884762454913098
# 1.2495297384073394
# 1.120554739961123
# 1.137857353567079
# 1.157267489519724
# 1.2069341380031182
# 1.0472999649611459
# 1.0712818767096344
# 1.0630946152203002
# 1.0904117592793952
# 1.1090005246469596
# 1.117549546055354
# 1.1069879062107248
# 1.155030549867722
# 1.238064731601297
# 1.0637571831821047
# 1.0771476768499595
# 1.0641731772169043
# 1.1149721086419753
# 1.2401121576737475
# 1.096225381276202
# 1.1184631540342063
# 1.1249883431430574
# 1.1780560624266145
# 1.163091732955921
# 1.063462108571639
# 1.2993894659824212
# 1.0789061771044934
# 1.0327761180148805
# 1.0965391060603036
# 1.2332813765629402
# 1.0087807464376244
# 1.035842314746243
# 1.2557937576447267
# 1.1313058217718501
# 1.1129111327220003
# 1.1564339104982018
# 1.0760413041759522
# 1.0651333103195109
# 1.1040096125784387
# 1.131795993585316
# 1.3196176591224777
# 1.1550152289469255
# 1.1447008791182833
# 1.0782513555875648
# 1.101801847646072
# 1.141255394206385
# 1.189738088073552
# 1.0885671109753419
# 1.1633178323397628
# 1.1229612173626853
# 1.1231209130330848
# 1.0683046976900006
# 1.258393507727287
# 1.0631888697270389
# 1.1913856657628206
# 0.998977232842784
# 1.964057947845832
# 1.7241280227454512
# 1.6323352036409404
# 1.7308981374502739
# 1.7008428265199842
# 1.618123131740246
# 2.052055420932553
# 1.748647261370936
# 1.8747784125404783
# 1.5196847326143532
# 1.6300446335311793
# 1.8474188486364007
# 1.5327933459109595
# 1.7436286713372624
# 1.6000945773487374
# 1.6090528591294018
# 1.7206396839179208
# 1.6374985137682583
# 1.5464066907396716
# 1.5766372717754533
# -----
# 1.649879866948925
# 2.052055420932553 1.3923613054134143

# %%
beta = 0.8; peps = 3.4
a = 1/(4*nsum(lambda k: (1/math.exp(peps*k))*X(k), [0,inf]))
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(a,2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 2.9075275607100615
# 2.9349351648750406
# 3.6677166850208716
# 3.247509956200137
# 2.557614988444689
# 3.312237877206582
# 3.313553205533688
# 3.129250452347729
# 3.781415767871767
# 3.0280806885689486
# 3.409949622372271
# 3.0432804234356383
# 3.3588897038473458
# 3.381382743665757
# 3.055764431075386
# 3.7481635750234625
# 3.93567451088554
# 3.9424013473364563
# 3.056803014368109
# 2.830700355140791
# 3.0479906505528054
# 3.042252953376496
# 3.591038661661451
# 3.4171987688643863
# 3.4638251246694036
# 2.77931968074493
# 3.7029271481883903
# 2.9858880418933906
# 3.1864910040330248
# 2.544468668883698
# 2.9218105735338615
# 3.108692676011502
# 2.75126685240611
# 4.0752683110704115
# 3.2923333668413055
# 2.7326874404566786
# 2.755418933432036
# 3.3697559568998914
# 3.4561572866098316
# 2.829918754981432
# 3.931961576397283
# 3.164703592329518
# 3.3174856154347534
# 2.9702400788964383
# 4.0963020911890125
# 3.0274806806059935
# 3.132302402311854
# 3.3116853389938883
# 3.0912926562448484
# 3.203253962848001
# 2.766977842318456
# 2.6671636063809308
# 3.0555949123529187
# 3.1900706031265305
# 4.465739669968627
# 2.932152378184174
# 3.6522700829880073
# 3.3511031054413887
# 3.5629179135350837
# 3.01996137356741
# 3.399483860091276
# 2.800109118328561
# 3.39210084497102
# 3.7999340735642657
# 2.608761697600574
# 2.9027355908834545
# 2.61644756365786
# 2.9908685393231043
# 2.6713925322955068
# 3.103379923693123
# 3.1961849246538305
# 2.9146414286470366
# 2.5281268229422964
# 3.056328869648914
# 2.3504534716201833
# 3.0738694261589172
# 3.583008656170347
# 3.1585837635181098
# 3.5781762883072834
# 3.436014417260207
# 3.8698953777361145
# 3.302546732285553
# 3.5873447480460654
# 2.6739379256106988
# 3.148207648396199
# 2.8868665620078366
# 3.0737481761003678
# 2.8012298137340705
# 3.3619252793380023
# 3.335585222740667
# 2.699092309035943
# 3.7651889557742373
# 3.767043154846019
# 2.662948484304989
# 2.8714961881058234
# 4.096723436680279
# 3.044532836445833
# 2.7848415292572044
# 3.3712689742178354
# 3.302005174013766
# -----
# 3.2017525275416987
# 4.465739669968627 2.3504534716201833
