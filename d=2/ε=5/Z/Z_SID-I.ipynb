# %%
from sympy import *
from scipy.optimize import minimize
from scipy import integrate
from scipy.integrate import quad
import matplotlib.pyplot as plt
import numpy as np
import math
import random
from mpmath import nsum, inf

# %%
#beta = 0
def g(z):
    return math.exp(-5*(abs(z)**1.1323514))

def b(k):
    return k

def X(k):
    return quad(lambda z1: quad(lambda z2: g(z1+z2-b(k)), max(0,b(k)-z1), b(k+1)-z1)[0], 0, b(k+1))[0]

def S(a,k):
    T = nsum(lambda i: (1/math.exp(5*i))*X(i), [0,k-1])
    return a*T

def ComputeZ(a,d):
    c = random.uniform(0,1/(2**d))
    #print(c)
    k = 0
    while(1):
        if S(a,k) <= math.fabs(c) and math.fabs(c) < S(a,k+1):
            break
        else:
            k += 1
    #print(math.fabs(c)-S(a,k))
    fun = lambda x: math.fabs(math.fabs(c)-S(a,k)-a*(1/math.exp(5*k))*quad(lambda z1: quad(lambda z2: g(z1+z2-b(k)), max(0,b(k)-z1), b(k)+x[0]-z1)[0], 0, b(k)+x[0])[0])
    bnds = ((0,1), (0,None))
    res = minimize(fun, (0.1,1), bounds = bnds)
    #print(res.fun, res.x)
    return b(k)+res.x[0] #||Z||_1

# %%
def Evaluation(a,d):
    Z = 0
    for i in range(100):
        Z += ComputeZ(a,d)
    return Z/100

# %%
a = 1/(4*nsum(lambda k: (1/math.exp(5*k))*X(k), [0,inf]))
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(a,2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 0.4643930187553715
# 0.3974465569936255
# 0.3901851009081796
# 0.4443746567893781
# 0.3871406051805706
# 0.39759214479070437
# 0.38318231762254223
# 0.37172337351380697
# 0.3942432878347228
# 0.41159888025380104
# 0.422441309544724
# 0.38670004200315666
# 0.4318737434929132
# 0.4293185221956305
# 0.4248476622418032
# 0.40717516879525506
# 0.40365271285310733
# 0.4112875839137786
# 0.4281740375951098
# 0.4111099912092028
# 0.4051100652457505
# 0.38473829447575497
# 0.37157895520759526
# 0.3803525566035821
# 0.4160632962953272
# 0.4001037963675858
# 0.34800977648654496
# 0.40179170807710085
# 0.47442398247552586
# 0.4076806766724237
# 0.4196034012182209
# 0.4210608486244823
# 0.36009799366784345
# 0.39937417492270527
# 0.4368155764859386
# 0.3927517326243101
# 0.3877275920662327
# 0.4272071163072331
# 0.4181331974491627
# 0.45281701477203756
# 0.37061159554435796
# 0.3280925848481933
# 0.3729791343897377
# 0.3746682715941976
# 0.41638786093888286
# 0.40444465463350254
# 0.40370179829497765
# 0.37717228345393217
# 0.34667479666727824
# 0.37867529147960766
# 0.4112095050336801
# 0.37722096855817855
# 0.44217574325630166
# 0.43471813778046653
# 0.4402641385571766
# 0.39203980697760216
# 0.37746698658422895
# 0.3523859255898707
# 0.3801139357849519
# 0.4212703833956873
# 0.325201089227878
# 0.430177013951589
# 0.36023895975523346
# 0.4118456123408908
# 0.43991144560166295
# 0.4455395315446048
# 0.4253713303320384
# 0.37316845480812527
# 0.47698436039930087
# 0.3870124629615742
# 0.3635058743653187
# 0.3785560257802007
# 0.3873636959275857
# 0.3870274954117409
# 0.36324228212535586
# 0.3690904571117666
# 0.4359528911103949
# 0.39550793805599405
# 0.3348698764536717
# 0.4194823853553138
# 0.39447569461619514
# 0.3754405586297348
# 0.4495174842562384
# 0.38567139948880813
# 0.36824138984000965
# 0.4077329675631113
# 0.4191787955443312
# 0.37698254215675087
# 0.40491531210880277
# 0.38511036316955044
# 0.40482550118688065
# 0.36571855731360964
# 0.40607701363878745
# 0.38069411855507135
# 0.3920025966155333
# 0.35383839418561713
# 0.35510669864138883
# 0.42552995370947583
# 0.3998929058367139
# 0.37570949518582664
# -----
# 0.39842887200758237
# 0.47698436039930087 0.325201089227878

# %%
beta = 0.2; peps = 5; r = 1.14274006
def g(z):
    return math.exp(-(peps/math.exp(beta*r))*(abs(z)**r))

def b(k):
    return (math.exp(beta)/(math.exp(beta)-1))*(math.exp(beta*k)-1)

def X(k):
    return quad(lambda z1: quad(lambda z2: g((z1+z2-b(k))/math.exp(beta*k)), max(0,b(k)-z1), b(k+1)-z1)[0], 0, b(k+1))[0]

def S(a,k):
    T = nsum(lambda i: (1/math.exp(peps*i))*X(i), [0,k-1])
    return a*T

def ComputeZ(a,d):
    c = random.uniform(0,1/(2**d))
    #print(c)
    k = 0
    while(1):
        if S(a,k) <= math.fabs(c) and math.fabs(c) < S(a,k+1):
            break
        else:
            k += 1
    #print(math.fabs(c)-S(a,k))
    fun = lambda x: math.fabs(math.fabs(c)-S(a,k)-a*(1/math.exp(peps*k))*quad(lambda z1: quad(lambda z2: g((z1+z2-b(k))/math.exp(beta*k)), max(0,b(k)-z1), b(k)+x[0]-z1)[0], 0, b(k)+x[0])[0])
    bnds = ((0,math.exp(beta*(k+1))), (0,None))
    res = minimize(fun, (0.1,1), bounds = bnds)
    #print(res.fun, res.x)
    return b(k)+res.x[0] #||Z||_1

# %%
a = 1/(4*nsum(lambda k: (1/math.exp(peps*k))*X(k), [0,inf]))
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(a,2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 0.5376660159726045
# 0.4953964096695907
# 0.5212380297182581
# 0.4751355459712487
# 0.4842370720937861
# 0.4509590827711433
# 0.4672901193431368
# 0.4850804644394322
# 0.48423835812231064
# 0.4709859634554778
# 0.5228908330950481
# 0.39813311016660236
# 0.4992365405465006
# 0.5120797869191439
# 0.42765517783191487
# 0.5276208729860451
# 0.5118222099751242
# 0.41782966143643124
# 0.507699555748155
# 0.5011184135724644
# 0.48458025324920684
# 0.48978139220756217
# 0.5264217048972702
# 0.46606383149446395
# 0.5118360497963647
# 0.46190059719868687
# 0.5495652914989488
# 0.4872987967209605
# 0.49698797318308685
# 0.5590224728627111
# 0.5660984260315997
# 0.5047583798496675
# 0.5772292174783816
# 0.4551787853740484
# 0.5149730558976262
# 0.5260029558436579
# 0.5152421912923566
# 0.47423629661381655
# 0.4467124734860946
# 0.5189641686035479
# 0.45056030889885046
# 0.49641789883908943
# 0.48348953000988976
# 0.48210998988758497
# 0.524975968501882
# 0.5111916044012035
# 0.49905887479975386
# 0.48388747649001984
# 0.5746752567174951
# 0.45125304167188973
# 0.47883600728481623
# 0.49150300427769816
# 0.4788815895398293
# 0.4491803450635265
# 0.43998373278219133
# 0.4905927636531697
# 0.5010963035130593
# 0.5219715060645619
# 0.5249937606396029
# 0.5382471858500106
# 0.5394840564948862
# 0.5355640736143612
# 0.51535216847445
# 0.5166925288838403
# 0.47679641338347123
# 0.4333237530147052
# 0.5402585994426999
# 0.5237098889889895
# 0.5461735461979061
# 0.584990489704127
# 0.5188399021447042
# 0.5416798526712786
# 0.48357906019481917
# 0.5054052984089767
# 0.46992908273368195
# 0.5314006739625896
# 0.4670498785496319
# 0.4988765498027905
# 0.4634059861814137
# 0.5899046310705036
# 0.5642542025196987
# 0.5223821400838337
# 0.5100627230720559
# 0.5128924433688226
# 0.5058718704432427
# 0.4019120874334292
# 0.5025764952215142
# 0.5172572560461988
# 0.5479177567132989
# 0.46778317942286
# 0.4727251278112773
# 0.5102344793977207
# 0.5097907472781604
# 0.5474007143730569
# 0.4968889362158033
# 0.5491112571063275
# 0.45956034487457
# 0.4978630415178328
# 0.4764185705383118
# 0.486197995805643
# -----
# 0.5004559148946408
# 0.5899046310705036 0.39813311016660236

# %%
beta = 0.4; peps = 5; r = 1.1553777
a = 1/(4*nsum(lambda k: (1/math.exp(peps*k))*X(k), [0,inf]))
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(a,2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 0.6568334929545592
# 0.6033027394895322
# 0.5779001451020467
# 0.6521885737683539
# 0.6622298957663044
# 0.6739607201244633
# 0.6064632774191818
# 0.5735346112762351
# 0.6614267356542772
# 0.7195020690375419
# 0.6459090155113164
# 0.6032273252112025
# 0.6185883241953074
# 0.6778025684246812
# 0.681751470928416
# 0.6470367903300221
# 0.7204815827110304
# 0.585810224387936
# 0.6563533273100339
# 0.6044245644506968
# 0.5634440755718053
# 0.5983876668254059
# 0.7658915344008136
# 0.6815103631700563
# 0.5437668445957221
# 0.7341186642569321
# 0.7010374364638919
# 0.6823245126356551
# 0.6815310077371426
# 0.6024321888077273
# 0.717581969821647
# 0.6408499862223997
# 0.5819942928213017
# 0.7033674053631498
# 0.5740129084158521
# 0.6121705934852707
# 0.5779863201613015
# 0.7598774039950653
# 0.6247388148098697
# 0.5944343166520286
# 0.574978225066885
# 0.6087637777148348
# 0.5717419105933557
# 0.6568737135886386
# 0.64816769723956
# 0.6393013675199858
# 0.5968511956624972
# 0.6497526344961133
# 0.7033470314424877
# 0.6828199756139017
# 0.6304798983787953
# 0.6998433056890409
# 0.607879897620587
# 0.5502323099088137
# 0.6661415339416118
# 0.5831143539210184
# 0.5729036099199366
# 0.6826600261303425
# 0.6853520590776483
# 0.6213976448859241
# 0.586457425095255
# 0.6022976858682582
# 0.6181164503300678
# 0.5825001680363092
# 0.7069973530656027
# 0.7340115451571464
# 0.6519409043873275
# 0.6604220370682053
# 0.5497400095353296
# 0.6231385062858383
# 0.7447775202989186
# 0.6362880924550555
# 0.6255128922864805
# 0.5805797229859632
# 0.6443232166172226
# 0.5401380139238647
# 0.6287058511184627
# 0.5440090889654862
# 0.5746284333703178
# 0.5800391406989864
# 0.6218885755541779
# 0.6620273911168202
# 0.6247984797913815
# 0.6184569750395528
# 0.6835071834566679
# 0.6702297567946982
# 0.6290209395039457
# 0.7106263517097591
# 0.6860568891163098
# 0.6266362061060312
# 0.6471127795077255
# 0.5924138943684517
# 0.6695163773909474
# 0.6849601734756093
# 0.6112372121215337
# 0.7080903381318103
# 0.6344220568698397
# 0.6246212804708257
# 0.6858854578913386
# 0.6205477794261722
# -----
# 0.6382946808407186
# 0.7658915344008136 0.5401380139238647

# %%
beta = 0.6; peps = 5; r = 1.17079993
a = 1/(4*nsum(lambda k: (1/math.exp(peps*k))*X(k), [0,inf]))
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(a,2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 0.8619590402406593
# 0.796555320005286
# 0.9229131080416068
# 0.8864079720951951
# 0.8719710411683289
# 0.8287004655765722
# 0.7622113088171883
# 0.8687969685176989
# 0.881618474548096
# 0.9006802711527014
# 0.8955587355193516
# 0.7630950334951934
# 0.8512488828990091
# 0.89723519377833
# 0.8841164943231774
# 0.7892156543451573
# 0.9555458822408158
# 0.841696235945648
# 0.7065193798597091
# 0.8779047228184332
# 0.877716306340999
# 0.7646071138107021
# 0.7415734111886013
# 0.7459952383556709
# 0.8825093820351537
# 0.6993386080582347
# 0.7959282925627759
# 0.8817447580479193
# 0.8203455426495004
# 0.9017322843043778
# 0.7186001209925179
# 0.8535556977209405
# 0.944097851270051
# 0.9145346183959977
# 0.7926828908110063
# 0.8424358724558952
# 0.8764600430421905
# 0.7496589812955139
# 0.8168129711660151
# 0.7965076398523471
# 0.860051375173604
# 0.7290928285299144
# 0.8024176472924464
# 0.8851958855924801
# 0.9131626517499276
# 0.813004173919511
# 0.8173316206739095
# 0.8368575404991476
# 0.8810248165761453
# 0.9012316486034547
# 0.7831936040112779
# 0.6955974492284764
# 0.7183795740562189
# 0.7700761977740364
# 0.8912116259418387
# 0.816404925916435
# 0.758197223139726
# 0.6972327181226937
# 0.7547677928036731
# 0.8761467711086042
# 0.9255355264398937
# 0.8223198641960876
# 0.7663410475286192
# 0.822276341010349
# 0.9452203662843192
# 0.8219439782912334
# 0.8623262094138784
# 0.8348970150589335
# 0.7956949796838457
# 0.9284708692665522
# 0.9610437461059367
# 0.8557489533831643
# 0.8819965842708265
# 0.8620370155534935
# 0.7881235153405727
# 0.7433155553246893
# 0.6824185482401391
# 0.7778383409903327
# 0.7794593831978499
# 0.8189120803774462
# 0.9016794073723493
# 0.8347164605042998
# 0.780988068876537
# 0.7350268924107568
# 0.7919559268212265
# 0.8548664005807405
# 0.8586464070882396
# 0.8895262339358212
# 0.763721989669859
# 0.8111577975528543
# 0.8447618640988241
# 0.884343115487842
# 0.8854867570441622
# 0.7379782666304479
# 0.8559375211456459
# 0.7495083844012644
# 0.7792199076427713
# 0.8264031599907737
# 0.6728867651275793
# 0.8331201353226265
# -----
# 0.8262921726212091
# 0.9610437461059367 0.6728867651275793

# %%
beta = 0.8; peps = 5; r = 1.19149831
a = 1/(4*nsum(lambda k: (1/math.exp(peps*k))*X(k), [0,inf]))
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(a,2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 1.3858260600959955
# 0.9554247289515257
# 1.2751997995035094
# 1.2146521110136481
# 1.4427728110547269
# 1.4257164893132837
# 1.098732622050996
# 1.283419725149695
# 1.3376100729472353
# 0.9722185879786087
# 1.1878436076057428
# 1.0742238767281558
# 1.3637883702816145
# 1.1529034396317694
# 1.2925915383359254
# 1.1000030734922532
# 1.107959068784302
# 1.2022535868329782
# 1.4080357949083555
# 1.1182088419167542
# 1.0306554613740544
# 1.1440419829100852
# 1.0848239270483706
# 0.9848435736522214
# 0.8934938253714167
# 1.1523922748185138
# 1.0735035005333695
# 1.0929089063546151
# 0.9817902100033699
# 1.0552664934097509
# 1.137162941221908
# 1.1045777254855063
# 1.1509121015137607
# 1.1176621524612802
# 1.0758358472560912
# 1.1520357842702558
# 1.2606981882385067
# 1.020978075456488
# 1.1819397512259717
# 1.1940281435215148
# 1.1402285055899477
# 1.0911054219394372
# 1.1376255061901166
# 1.1851700141799708
# 1.1988188898361254
# 1.0252327893609472
# 1.0213908021997755
# 1.3877629459068508
# 1.127043353769733
# 1.282553709020387
# 0.9157776834340859
# 1.0650734077275243
# 1.0824242238160027
# 0.9270734044469848
# 0.939131285573878
# 1.1041066086196094
# 1.047518717932887
# 1.2281514864069647
# 1.3076487191484116
# 1.011634954797729
# 1.1164096915570583
# 1.2531097754817204
# 1.105300495473863
# 0.8732555849170618
# 1.0184775708787628
# 1.2257066734971052
# 1.0352477657004888
# 1.071300685894859
# 0.9351576934412222
# 0.9550921712372754
# 0.9674681726130254
# 0.9916609927575606
# 1.3139991899876795
# 1.160479997732835
# 1.1990605954911586
# 1.0825825409937722
# 1.1928893271144072
# 1.0443093471907376
# 1.137374672884106
# 1.2072219620309168
# 1.0850046979952734
# 1.1848359299547055
# 0.9707603957607486
# 1.0649593349128967
# 1.0963323547375226
# 1.3664286433107824
# 1.0627664239434107
# 1.3116015787801802
# 1.1014912911376988
# 1.2569101511525884
# 1.04816581629725
# 1.2037348656358808
# 1.129326842501136
# 1.223101521661974
# 1.0795884881665818
# 1.0053451546303074
# 0.876312140282574
# 1.301039935943509
# 1.424405072018279
# 1.0795660956297457
# -----
# 1.1327218914393014
# 1.4427728110547269 0.8732555849170618
