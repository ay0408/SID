# %%
from scipy.optimize import minimize
from scipy import integrate
from scipy.integrate import quad
import matplotlib.pyplot as plt
import numpy as np
import math
import random
import warnings; warnings.simplefilter('ignore')

# %%
def h(z):
    return (2**(1/2))/(math.pi*(z**4+1))

def ComputeZ(d):
    c = random.uniform(-0.5,0.5)
    fun = lambda x: math.fabs(math.fabs(c)-quad(lambda z: h(z), 0, x[0])[0])
    bnds = ((0,None), (0,None))
    res = minimize(fun, (1,1), bounds = bnds)
    return res.x[0]*(c/math.fabs(c))*d

# %%
def Evaluation(d):
    Z = 0
    for i in range(100):
        Z += math.fabs(ComputeZ(d))
    return Z/100

# %%
eps = 5
def alpha(beta):
    k = 2-(6*beta*2)/eps
    return (eps/(2*(3**(3/4))))*k

# %%
beta = 0
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = (1/alpha(beta))*Evaluation(2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M,m)
# Out:
# 0.5860687119404934
# 0.7024527995420292
# 0.6374922105663019
# 0.5866218481543998
# 0.7972101461514921
# 0.792564502249486
# 0.6578974730031966
# 0.6800545179133386
# 0.86676971504515
# 0.7456338366458427
# 0.6430238605320828
# 0.6168438669495281
# 0.6333621033611542
# 0.5451709177505344
# 0.6165219065710209
# 0.6562936346262538
# 0.6729824219500333
# 0.6483913027810696
# 0.6667648321032253
# 0.5825041215548283
# 0.682017264932637
# 0.6288270019040617
# 0.686078611847637
# 0.5317956370469558
# 0.6227397884789269
# 0.5335916751635629
# 0.7711992506771966
# 0.7068861930624023
# 0.608848981971825
# 0.5659109574365155
# 0.6934023263963648
# 0.6173191653579098
# 0.5977281735355077
# 0.6211733885610505
# 0.6002975141358141
# 0.6803411372435203
# 0.5909202674541117
# 0.6206731101927528
# 0.589768305120333
# 0.620337466491564
# 0.6290994588300393
# 0.5945097009308016
# 0.538546442734995
# 0.627730704290882
# 0.7495813478894634
# 0.6424053424062782
# 0.6678867847772265
# 0.6365561621706844
# ...

# %%
beta = 0.2
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = (1/alpha(beta))*Evaluation(2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M,m)
# Out:
# 0.8539238275398127
# 0.7264066969749261
# 0.7431094631209485
# 0.8684574007984559
# 0.892690286182227
# 0.8157553700514801
# 0.862214478353275
# 0.749260273707738
# 0.8283907108088402
# 0.6948097010690812
# 0.8805760231027532
# 0.9207868215794535
# 0.912228515155606
# 0.7075166344974242
# 0.772907953252795
# 0.8611661610051976
# 0.8535079733937339
# 0.8700999120795498
# 0.8040133615609778
# 0.7998062624370885
# 0.7370881501069575
# 0.7916179650725812
# 0.8354910271208155
# 0.9436232798691369
# 0.9711281355410512
# 0.8225425763421059
# 0.718020015995693
# 0.7800767618092284
# 0.8700741099314042
# 0.920713957146551
# 0.8625981186261057
# 0.9027949494158003
# 0.9055729519969931
# 0.8664748576365917
# 0.759487931444598
# 0.9342596547847003
# 0.8495518413316404
# 0.9968696874287457
# 0.8040940101961518
# 0.707138112270502
# 0.8072673006230069
# 0.7969334488214956
# 0.7289862794622621
# 0.7150895785776101
# 0.7347779391214233
# 0.8192230356796932
# 0.7273399542977141
# 0.844168004792155
# ...

# %%
beta = 0.4
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = (1/alpha(beta))*Evaluation(2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M,m)
# Out:
# 1.2114375264689108
# 1.1296134411837684
# 1.2562331909392142
# 1.0089954091497364
# 1.2253156889986028
# 1.3425642953922974
# 1.3251170012078024
# 1.328794889317999
# 1.2286695871347664
# 1.232487132483493
# 1.1901119101630007
# 1.4208785835044107
# 1.2531102204965079
# 1.3647798127601096
# 1.1615153857282496
# 1.3451804923370616
# 1.3773034704355405
# 1.0576959152639263
# 1.1661816924776465
# 1.224146436292114
# 1.1446823559571653
# 1.2194820506790862
# 1.228981381849704
# 1.261052397516168
# 1.3978193901878642
# 0.9463889403765812
# 1.3547755960140115
# 1.3238984804945853
# 1.3548035089467778
# 1.500023987398634
# 1.143078751135359
# 1.1361564723178685
# 1.2500332159876493
# 1.111254735214133
# 1.3426356362207015
# 1.0573249945434897
# 1.2111852853121208
# 1.3248452349626896
# 1.1351601141923184
# 1.4518803471773465
# 1.2218103668112306
# 1.4001577502968732
# 1.1912924631551638
# 1.3295129661557403
# 1.4285697141384708
# 1.2952344148914356
# 1.2076987597790616
# 1.2460560270846555
# ...

# %%
beta = 0.6
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = (1/alpha(beta))*Evaluation(2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M,m)
# Out:
# 2.5338491028787353
# 2.471693682833501
# 2.2082043401500258
# 2.311136616792365
# 2.4966370602928913
# 2.387258032661778
# 2.2796786489045675
# 2.1080501817617416
# 2.404387515048126
# 2.296682179329825
# 2.5864004253253943
# 2.0320398167102622
# 2.0197534594677515
# 2.080452842726082
# 2.8931327916600544
# 2.413184183504219
# 2.265183722885057
# 2.514468431208295
# 2.1590545631961637
# 2.2125024120009567
# 2.386315920202405
# 2.683256085760524
# 2.230826613636046
# 2.07235083877822
# 1.9924940409573941
# 2.298251303353795
# 2.251092210575798
# 1.8794355246056562
# 2.1447602772859593
# 2.186852287193432
# 2.2753984151090023
# 2.2990079142813578
# 2.3343346004345906
# 2.1915867337073727
# 2.2757157550784237
# 2.1184706892616036
# 2.581239813058931
# 2.74925590547021
# 2.1703851777423773
# 2.3221774845158984
# 2.484930682038197
# 2.1187555588130778
# 1.9651123411241818
# 2.437621758098208
# 2.470061826454757
# 2.032609718385972
# 2.516057239984293
# 2.419714291792336
# ...

# %%
beta = 0.8
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = (1/alpha(beta))*Evaluation(2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M,m)
# Out:
# 16.182834636493695
# 16.614686937923246
# 17.321667735150868
# 14.155509385915085
# 15.280905264387805
# 17.511741120719
# 16.124691726895225
# 13.106572762350144
# 19.630737873425982
# 18.442225228206034
# 14.52532761059669
# 17.43125929367364
# 19.067223762360523
# 15.259911267313274
# 15.665803943812612
# 16.306489262718735
# 15.363408362592097
# 15.862162396788225
# 15.887655080266773
# 17.38676400490327
# 18.0865740252525
# 15.520890161533163
# 14.309396404918248
# 18.66316310379587
# 15.227117809450624
# 16.101895772902683
# 17.17230568559443
# 13.551435745500315
# 18.522577319431054
# 16.76742030607086
# 17.16875275111471
# 14.031063757709655
# 14.605841826367348
# 18.33483763562298
# 15.717214280982354
# 14.625950395386061
# 16.45152634177884
# 17.741771280604542
# 16.91273592590329
# 20.52408184119394
# 15.130730103612944
# 16.918042234428313
# 17.547404193567964
# 18.82855704081843
# 17.438290153365042
# 17.684928848835852
# 14.886237079646632
# 14.834227290722534
# ...
