# %%
from sympy import *
from scipy.optimize import minimize
from scipy import integrate
from scipy.integrate import quad
import matplotlib.pyplot as plt
import numpy as np
import math
import random
from mpmath import nsum, inf

# %%
#beta = 0
def g(z):
    return -((math.exp(5)-1)/math.exp(5))*(abs(z)**0.206116)+1

def b(k):
    return k

def X(k):
    return quad(lambda z1: quad(lambda z2: g(z1+z2-b(k)), max(0,b(k)-z1), b(k+1)-z1)[0], 0, b(k+1))[0]

def S(a,k):
    T = nsum(lambda i: (1/math.exp(5*i))*X(i), [0,k-1])
    return a*T

def ComputeZ(a,d):
    c = random.uniform(0,1/(2**d))
    #print(c)
    k = 0
    while(1):
        if S(a,k) <= math.fabs(c) and math.fabs(c) < S(a,k+1):
            break
        else:
            k += 1
    #print(math.fabs(c)-S(a,k))
    fun = lambda x: math.fabs(math.fabs(c)-S(a,k)-a*(1/math.exp(5*k))*quad(lambda z1: quad(lambda z2: g(z1+z2-b(k)), max(0,b(k)-z1), b(k)+x[0]-z1)[0], 0, b(k)+x[0])[0])
    bnds = ((0,1), (0,None))
    res = minimize(fun, (0.1,1), bounds = bnds)
    #print(res.fun, res.x)
    return b(k)+res.x[0] #||Z||_1

# %%
def Evaluation(a,d):
    Z = 0
    for i in range(100):
        Z += ComputeZ(a,d)
    return Z/100

# %%
a = 1/(4*nsum(lambda k: (1/math.exp(5*k))*X(k), [0,inf]))
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(a,2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 0.5214020163244613
# 0.49301648755728983
# 0.5720693312799576
# 0.48250443858180475
# 0.4547878622800034
# 0.5166645064133037
# 0.5081180853064402
# 0.5225721448371728
# 0.4540183798533037
# 0.4908158693885137
# 0.4923789931645075
# 0.5074351873521799
# 0.5000160065867605
# 0.4866259151470811
# 0.48546687924013016
# 0.4780848074027804
# 0.4919866738248934
# 0.46592399087359987
# 0.4514550609946088
# 0.5111310913181303
# 0.5146097326126674
# 0.45600179031820554
# 0.5200465457615515
# 0.4803036513960467
# 0.5068240815775128
# 0.4632928424647642
# 0.48419840099673556
# 0.4936620778396445
# 0.5203188971659916
# 0.5082106431325641
# 0.48144600248510444
# 0.515027783792775
# 0.4756180628523976
# 0.5208703107440772
# 0.5148259359286568
# 0.49624114730180635
# 0.499528602385102
# 0.5066978437088173
# 0.5089306833259336
# 0.47587033196571155
# 0.4815346444438963
# 0.49736560466185553
# 0.5294372709476084
# 0.5315520995174196
# 0.5155621172785225
# 0.49102614067735373
# 0.48040652842083176
# 0.4813227076016651
# 0.5324576862224408
# 0.5005459158038106
# 0.5266999579728027
# 0.4679218659488852
# 0.502841624446765
# 0.5341560725543301
# 0.4894245136919928
# 0.5205911683632186
# 0.47439190098179645
# 0.501275162826692
# 0.4786391137707416
# 0.5385425521863847
# 0.5145384753663423
# 0.4930698712226234
# 0.5220790520280729
# 0.4966848918659013
# 0.49375918254789475
# 0.49694563045357276
# 0.49215890129203244
# 0.5017254425811758
# 0.4962527037497989
# 0.5623942309486014
# 0.47876293614923837
# 0.4686916449735839
# 0.4740397151570667
# 0.4828744350187611
# 0.5061283044756488
# 0.48408320212171896
# 0.4778154735058777
# 0.4930278183779584
# 0.5138109652562861
# 0.49195729537856464
# 0.5576812092753837
# 0.5238774632398029
# 0.47873171438444845
# 0.43638663424134655
# 0.46975883881738734
# 0.5058057079324798
# 0.4415137261630199
# 0.4534988055875104
# 0.4783861697883068
# 0.4622878061852228
# 0.5003062261165087
# 0.5291969191061114
# 0.49383188593890276
# 0.5047510320937288
# 0.49388580878401456
# 0.5284806800886669
# 0.5136078682921483
# 0.5276658633706064
# 0.49465356202487565
# 0.4985954433788277
# -----
# 0.4973839728108201
# 0.5720693312799576 0.43638663424134655

# %%
beta = 0.2; peps = 5; r = 0.20744623
def g(z):
    return -((math.exp(peps)-1)/math.exp(peps+beta*r))*(abs(z)**r)+1

def b(k):
    return (math.exp(beta)/(math.exp(beta)-1))*(math.exp(beta*k)-1)

def X(k):
    return quad(lambda z1: quad(lambda z2: g((z1+z2-b(k))/math.exp(beta*k)), max(0,b(k)-z1), b(k+1)-z1)[0], 0, b(k+1))[0]

def S(a,k):
    T = nsum(lambda i: (1/math.exp(peps*i))*X(i), [0,k-1])
    return a*T

def ComputeZ(a,d):
    c = random.uniform(0,1/(2**d))
    #print(c)
    k = 0
    while(1):
        if S(a,k) <= math.fabs(c) and math.fabs(c) < S(a,k+1):
            break
        else:
            k += 1
    #print(math.fabs(c)-S(a,k))
    fun = lambda x: math.fabs(math.fabs(c)-S(a,k)-a*(1/math.exp(peps*k))*quad(lambda z1: quad(lambda z2: g((z1+z2-b(k))/math.exp(beta*k)), max(0,b(k)-z1), b(k)+x[0]-z1)[0], 0, b(k)+x[0])[0])
    bnds = ((0,math.exp(beta*(k+1))), (0,None))
    res = minimize(fun, (0.1,1), bounds = bnds)
    #print(res.fun, res.x)
    return b(k)+res.x[0] #||Z||_1

# %%
a = 1/(4*nsum(lambda k: (1/math.exp(peps*k))*X(k), [0,inf]))
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(a,2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 0.6101301851277665
# 0.6060177628326933
# 0.6069376120832094
# 0.665422837718847
# 0.5964692790393359
# 0.6124289959987238
# 0.6899617749138476
# 0.5965357361350585
# 0.6481533253109504
# 0.6025095523582293
# 0.6403886495355102
# 0.5267081316055323
# 0.6805792479067501
# 0.6339914535602804
# 0.622493574114316
# 0.5925001719833878
# 0.5423671355325506
# 0.6808009709230896
# 0.5837878601290746
# 0.6186096674813758
# 0.6251951466273756
# 0.5984282567482772
# 0.6693823841200205
# 0.6334567966814756
# 0.5890827995196236
# 0.6623290898457119
# 0.5873868340143341
# 0.6434633085612198
# 0.598412567559685
# 0.5510964912292271
# 0.6791025743217516
# 0.655811113890095
# 0.6009205141776641
# 0.630640667293915
# 0.5823854608961485
# 0.5978686971740192
# 0.5786565863308809
# 0.6440323255987042
# 0.5890372266360597
# 0.5935442675888523
# 0.6560003218712884
# 0.6709076340867862
# 0.6552602912992026
# 0.6443530083127649
# 0.5879682346626786
# 0.6426827021066377
# 0.6826514516194817
# 0.658969873339395
# 0.6811667645395122
# 0.632895925629416
# 0.57739311732153
# 0.621932567483151
# 0.5489452830614554
# 0.6173106549672459
# 0.5966825092994482
# 0.6352354626282231
# 0.5948139171757988
# 0.5937362803314911
# 0.6792423711927895
# 0.5858234881342362
# 0.6408105867497743
# 0.6351955503417421
# 0.6128572649010819
# 0.604005957239317
# 0.599948582326529
# 0.6505276711141729
# 0.6311922644640324
# 0.6636802945515431
# 0.6470529235837899
# 0.6923911128728816
# 0.6206730266191536
# 0.6454573183169123
# 0.6094336561024367
# 0.660572598247591
# 0.5868809505723283
# 0.5420181192257284
# 0.5751485360528326
# 0.5901276182334617
# 0.6723364554735184
# 0.6460435574314383
# 0.6278383159376503
# 0.5838970254321193
# 0.6354183835437108
# 0.6422322726883896
# 0.6878405812754963
# 0.6197735151454933
# 0.5978745779101093
# 0.6323397415337431
# 0.5833770162736129
# 0.6460392017361041
# 0.6034256034920495
# 0.619862835361724
# 0.5911235100009367
# 0.5229351347757073
# 0.6812095168337484
# 0.64229185929673
# 0.6020363032026137
# 0.6216084690441962
# 0.6062896822450965
# 0.6296758062485474
# -----
# 0.6213444228856616
# 0.6923911128728816 0.5229351347757073

# %%
beta = 0.4; peps = 5; r = 0.20937776
a = 1/(4*nsum(lambda k: (1/math.exp(peps*k))*X(k), [0,inf]))
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(a,2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 0.780329181298626
# 0.8053376356616039
# 0.7055629412083735
# 0.7729839569037733
# 0.7741055408323476
# 0.749515785325296
# 0.7606329168862921
# 0.810709322078679
# 0.764842318602631
# 0.7657644545655751
# 0.7781684107764427
# 0.7881409783125936
# 0.80813241177155
# 0.7385405587437743
# 0.7675367498255612
# 0.7168392223408336
# 0.8261927571166613
# 0.8273476653548153
# 0.7185222986346408
# 0.7844190764616359
# 0.8058487862586138
# 0.775788370973697
# 0.8151526118069448
# 0.8047137436247911
# 0.7421299072884563
# 0.790329596655927
# 0.7692950742628097
# 0.836770030527467
# 0.7771502024059836
# 0.8679815128682878
# 0.7561455211860951
# 0.8048181862293399
# 0.8471705271838775
# 0.7335748105062538
# 0.7344113296015357
# 0.7814943128523937
# 0.745795781069008
# 0.7787867849128223
# 0.7996795792219715
# 0.8303687928326349
# 0.7488800604973292
# 0.7567347235159542
# 0.7736274339785766
# 0.8486142979095723
# 0.8018665880504134
# 0.8892462655839539
# 0.770080731060264
# 0.7755687322698488
# 0.7611513082181577
# 0.783246511396672
# 0.8374972954507739
# 0.7692205829309102
# 0.7918474197961421
# 0.8283002795190455
# 0.7218085136031007
# 0.7698322918065496
# 0.7413896685594765
# 0.7346010985373177
# 0.7351205169826865
# 0.6767068850853755
# 0.8425833453049516
# 0.7552180652243343
# 0.8505807405342266
# 0.6753142930536746
# 0.828038973596979
# 0.7391458248696208
# 0.7913680027655297
# 0.7762508021955011
# 0.7915925081779436
# 0.7634751318812956
# 0.826630524366952
# 0.8053518013216295
# 0.7155340521051826
# 0.7993115575488713
# 0.707929097900791
# 0.7827304213146979
# 0.785071917136293
# 0.7487813894703244
# 0.8240969300454621
# 0.7722671821096463
# 0.7754983069578785
# 0.803078544955614
# 0.7375349429897463
# 0.7450748146118944
# 0.6910940760581632
# 0.7576368638405895
# 0.750876255123554
# 0.7826965865449645
# 0.7617106336889121
# 0.7696529853883526
# 0.758496181087561
# 0.8461900421120123
# 0.7762267739622243
# 0.8589590138681522
# 0.8455355929078334
# 0.726172101124779
# 0.7503338955738941
# 0.7459313879974033
# 0.8233266245010077
# 0.7370896508668827
# -----
# 0.7778075868480805
# 0.8892462655839539 0.6753142930536746

# %%
beta = 0.6; peps = 5; r = 0.21153137
a = 1/(4*nsum(lambda k: (1/math.exp(peps*k))*X(k), [0,inf]))
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(a,2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 1.02054231220828
# 0.8551960099302355
# 1.0438627393107327
# 0.9060315233878938
# 1.1679250826211685
# 1.1684537068621546
# 1.0305740676589656
# 0.9866604679016988
# 0.9853257472495378
# 0.9789695337702683
# 0.9927438327220577
# 1.0773394563666274
# 1.0644543941885238
# 0.9420210481741768
# 0.9189577165304237
# 0.9664122138513253
# 1.0554444640906626
# 0.9375448013543424
# 1.0411026808675836
# 0.8728371122751772
# 0.9193455139431331
# 1.0084073795800619
# 1.0875077683063346
# 0.8238925063850818
# 0.9970942615330255
# 1.0889031219863017
# 0.9824172970556238
# 1.1760837138235776
# 1.0725896089816735
# 1.0083695903418386
# 1.0767171571021725
# 1.0746097530052336
# 1.0210189284781335
# 0.8920755422343208
# 0.9871593740900266
# 1.0909865469234425
# 0.9240780100629293
# 1.0184651975331591
# 0.9693022889312742
# 1.060663731203637
# 1.0246319280616485
# 1.0082783997458227
# 0.9258712501570824
# 0.9564042609699718
# 0.9340578936723775
# 1.1099819272857088
# 0.914161718322899
# 1.0803815530850729
# 1.1478212502949212
# 1.0563081955183329
# 1.0603892597864368
# 0.9765721435317742
# 0.982873639458369
# 1.0752118159847674
# 1.082379877035124
# 0.924497577975241
# 1.0785795162745644
# 0.9402499715259529
# 1.0365216201985215
# 1.0284628697393334
# 0.9650964844665925
# 0.9542553523540809
# 1.005537307402115
# 0.9683802193382002
# 1.0157061047657368
# 1.084237766956325
# 0.9703595349414649
# 0.9863048554610117
# 1.0668513221237468
# 0.9725504337494318
# 0.9812169702752062
# 0.9517755986009722
# 1.0302350284861905
# 0.9739262783741697
# 0.9959445263432647
# 0.9180104400659433
# 0.9343470679430821
# 0.9525594629909506
# 1.000158909745532
# 1.1336372019780274
# 1.047080852952984
# 0.9862192305598191
# 0.8226277335511177
# 1.162131197726298
# 1.0161451193972706
# 0.9666859905691347
# 1.006745841444242
# 0.9226872555692546
# 0.9455779285914919
# 1.0398033476604556
# 1.1372746022541371
# 0.9620080758998232
# 0.9586418692419869
# 1.1221437951257993
# 0.9419701939573314
# 0.9389130230416058
# 1.0200656399693246
# 1.1021445332354964
# 0.9298115426913196
# 0.9802599766282397
# -----
# 1.0050575148787595
# 1.1760837138235776 0.8226277335511177

# %%
beta = 0.8; peps = 5; r = 0.21323198
a = 1/(4*nsum(lambda k: (1/math.exp(peps*k))*X(k), [0,inf]))
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(a,2)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 1.1277447028627035
# 1.459784718679114
# 1.327908348539316
# 1.35117171449241
# 1.3011777569273255
# 1.4702140004724695
# 1.348761241218142
# 1.370102447188742
# 1.3014949916758218
# 1.2691169324364737
# 1.074507812558312
# 1.3044920466086287
# 1.2504295000575685
# 1.2692874559446865
# 1.3557657717347755
# 1.336365922036454
# 1.064977705970054
# 1.5861636074705938
# 1.2293898771979128
# 1.1531177139909703
# 1.2638938912918496
# 1.273903749802667
# 1.345694498939651
# 1.3256629592860094
# 1.3211584529424159
# 1.2551452120947937
# 1.3192222680421175
# 1.5122629940476506
# 1.3600206106763495
# 1.1813707809031624
# 1.3050672936682925
# 1.2406749713503458
# 1.3045390970127164
# 1.2316563035319517
# 1.4775718347082663
# 1.417716817701396
# 1.4806980966782168
# 1.3507942994803617
# 1.4753702402159883
# 1.3893603648911537
# 1.4170983160763584
# 1.268430052638365
# 1.0595094704380617
# 1.5979171541698447
# 1.507579386191616
# 1.3865055271053552
# 1.2664175481538282
# 1.201144133787147
# 1.168989383258072
# 1.2813789819178505
# 1.2202445441395782
# 1.6305564004213418
# 1.301068277574849
# 1.4738321339699405
# 1.2729282024133952
# 1.5621498142535366
# 1.3218586754239765
# 1.2650914498823878
# 1.5478256024458799
# 1.4315411785945351
# 1.2136997713842235
# 1.3684297892482207
# 1.2958973659904092
# 1.2095176131206489
# 1.4105467250332941
# 1.291877539989101
# 1.2778231406286686
# 1.3498960327481748
# 1.3179065397127099
# 1.2752091318722354
# 1.280734399039416
# 1.1578290132652322
# 1.1606974924161038
# 1.2870550353517647
# 1.0130977816379845
# 1.235748548886872
# 1.227522441802238
# 1.4746837627490967
# 1.2598745789117387
# 1.2097413334349172
# 1.4464036096555788
# 1.1315851142765188
# 1.2881611488244116
# 1.2936110268620544
# 1.2460170581764
# 1.2478371825651984
# 1.4424019224648281
# 1.4180916134281747
# 1.3022036723394175
# 1.321545526937972
# 1.244359402633454
# 1.3406678020536558
# 1.338737827835863
# 1.1505526781500397
# 1.0667700916495344
# 1.2941217273224603
# 1.4003728579727843
# 1.4768166066623438
# 1.3508948494559403
# 1.227964474275104
# -----
# 1.3131272946894847
# 1.6305564004213418 1.0130977816379845
