# %%
from sympy import *
from scipy.optimize import minimize
from scipy import integrate
from scipy.integrate import quad

# %%
def E(peps,beta,r):
    c,e = quad(lambda z: z*(1/((exp(peps)-1)*log(z**r+1)+log(exp(beta*r)+1))),0,exp(beta))
    m,e = quad(lambda z: 1/((exp(peps)-1)*log(z**r+1)+log(exp(beta*r)+1)),0,exp(beta))
    return 1/(exp(peps-2*beta)-1) + ((exp(peps-beta)-1)/(exp(peps-2*beta)-1))*(1/exp(beta))*(c/m)

def g(z,beta,peps,r):
    return 1/((exp(peps)-1)*log(z**r+1)+log(exp(beta*r)+1))

def S(peps,beta,r):
    fun1 = lambda z: -g(z[0],beta,peps,r)/g(z[0]+1,beta,peps,r)
    bnds1 = ((0,exp(beta)-1), (0,None))
    res1 = minimize(fun1, (0,0), bounds = bnds1)
    #print(log(-res1.fun).evalf())
    fun2 = lambda z: -exp(peps)*g(z[0],beta,peps,r)/g((z[0]+1-exp(beta))/exp(beta),beta,peps,r)
    bnds2 = ((exp(beta)-0.999,exp(beta)), (0,None))
    res2 = minimize(fun2, (exp(beta)-1, 0), bounds = bnds2)
    #print(log(-res2.fun).evalf())
    x = max(-res1.fun, -res2.fun)
    return log(x)

# %%
eps = 2; beta = 0
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.480101607332749 [2.         1.88750626]

# %%
beta = 0.08
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.547150819276638 [1.99214431 1.72192834]

# %%
beta = 0.16
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.624314095132694 [1.99078443 1.81111645]

# %%
beta = 0.24
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.719124444554853 [1.98884087 1.8942718 ]

# %%
beta = 0.32
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.838938422604001 [1.98484096 1.97160634]

# %%
beta = 0.40
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.995851436883127 [1.97755108 2.04334364]

# %%
beta = 0.48
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 1.21117372735399 [1.96594924 2.10728636]

# %%
beta = 0.56
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 1.52616762608397 [1.94918609 2.16216191]

# %%
beta = 0.64
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 2.03236402509312 [1.92658802 2.2063831 ]

# %%
beta = 0.72
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 2.98144415706438 [1.89763629 2.23890409]

# %%
beta = 0.80
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 5.40810559076576 [1.86193354 2.25952158]

# %%
beta = 0.88
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 24.8568756975798 [1.81916369 2.26909889]
