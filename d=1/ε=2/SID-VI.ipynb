# %%
from sympy import *
from scipy.optimize import minimize
from scipy import integrate
from scipy.integrate import quad

# %%
def E(peps,beta):
    return 1/(exp(peps-2*beta)-1) + ((exp(peps-beta)-1)/(exp(peps-2*beta)-1))*(1/2)

def a(peps,beta):
    return peps

# %%
eps = 2; beta = 0

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.656517642749666 [2. 0.]

# %%
beta = 0.08

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.758091759231337 [1.92 0.  ]

# %%
beta = 0.16

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.890979098935090 [1.84 0.  ]

# %%
beta = 0.24

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 1.07296848697801 [1.76 0.  ]

# %%
beta = 0.32

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 1.33833035210720 [1.68 0.  ]

# %%
beta = 0.40

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 1.76253473968050 [1.6 0. ]

# %%
beta = 0.48

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 2.55052437170746 [1.52 0.  ]

# %%
beta = 0.56

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 4.52220709926129 [1.44 0.  ]

# %%
beta = 0.64

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 18.3367796220436 [1.36 0.  ]
