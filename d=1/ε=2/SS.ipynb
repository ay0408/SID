# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
def SS1(eps,beta):
    k = 2-(6*beta)/eps
    alpha = (eps/(2*(3**(3/4))))*k
    return 1/(alpha*(2**(1/2)))

def SS2(eps,beta):
    k = 2-(6*beta)/eps
    alpha = (eps/4)*k
    return (1/alpha)*(2/(math.pi))

def SS3(eps,beta):
    k = 2-(10*beta)/eps
    alpha = (eps/(2*(5**(5/6))))*k
    return 1/(alpha*(3**(1/2)))

# %%
beta = [0.08*i for i in range(12)]

# %%
eps = 2
for i in range(9):
    print(SS1(eps,beta[i]))
# Out:
# 0.8059274488676563
# 0.9158266464405185
# 1.0604308537732319
# 1.259261638855713
# 1.5498604785916466
# 2.014818622169141
# 2.878312317384487
# 5.0370465554228545
# 20.14818622169139

# %%
for i in range(9):
    print(SS2(eps,beta[i]))
# Out:
# 0.6366197723675814
# 0.7234315595086153
# 0.8376575952205019
# 0.994718394324346
# 1.2242687930145795
# 1.5915494309189537
# 2.273642044169933
# 3.978873577297386
# 15.915494309189521

# %%
for i in range(5):
    print(SS3(eps,beta[i]))
# Out:
# 1.103784727315685
# 1.3797309091446064
# 1.8396412121928085
# 2.7594618182892128
# 5.518923636578426
