# %%
from sympy import *
from scipy.optimize import minimize
from scipy import integrate
from scipy.integrate import quad
import matplotlib.pyplot as plt
import numpy as np
import math
import random

# %%
#beta = 0
def g(z):
    return 1

def b(k):
    return k

def S(k):
    return (1/2)*(1-(1/math.exp(5*k)))

def ComputeZ(d):
    c = random.uniform(-0.5,0.5)
    #print(c)
    k = 0
    while(1):
        if S(k) <= math.fabs(c) and math.fabs(c) < S(k+1):
            break
        else:
            k += 1
    a = ((math.exp(5)-1)/(2*math.exp(5)))*(1/quad(lambda z: g(z),0,1)[0])
    fun = lambda x: math.fabs(math.fabs(c)-S(k)-(1/exp(5*k))*quad(lambda z: a*g(z),0,x[0])[0])
    bnds = ((0,1), (0,None))
    res = minimize(fun, (0.5,1), bounds = bnds)
    #print(res.fun, res.x)
    return (b(k)+res.x[0])*(c/math.fabs(c))

# %%
def Evaluation(d):
    Z = 0
    for i in range(100):
        Z += math.fabs(ComputeZ(d))
    return Z/100

# %%
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(1)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 0.4753242143985139
# 0.5405747788249637
# 0.5247074006918869
# 0.508558378385558
# 0.4859128014104336
# 0.4693864856654577
# 0.5156149797518972
# 0.489014296497629
# 0.546841576004719
# 0.48742930211687613
# 0.5912567701190018
# 0.4786948472256947
# 0.4799949938757391
# 0.5329558781846733
# 0.5701980762784857
# 0.4917642780679459
# 0.5076839812570821
# 0.49747691054403714
# 0.5068070169120928
# 0.5054972994986631
# 0.46560207066641335
# 0.4863302850099589
# 0.4818830861163484
# 0.5119990895495768
# 0.4761086300208882
# 0.4676445267722071
# 0.4880237251839168
# 0.5602717791541935
# 0.46961550685592923
# 0.5295207643428949
# 0.5032636336873767
# 0.46895605071784835
# 0.542285405516634
# 0.5067582716833001
# 0.5157933507418716
# 0.5048277549455185
# 0.5391454881080296
# 0.4546569043310341
# 0.5073051362215762
# 0.5138731938011712
# 0.5127091648060277
# 0.4798752203318095
# 0.4715618312805614
# 0.46464655868946353
# 0.5092878771408484
# 0.48249027263459476
# 0.4508949476210592
# 0.49085500877064736
# 0.49904428964959374
# 0.4869714319186123
# 0.5316848912012163
# 0.5297756086183109
# 0.5046983685697205
# 0.5444452604173692
# 0.4910528160181131
# 0.509297292137977
# 0.4908049495873905
# 0.5368132546112134
# 0.5187525384406629
# 0.5100655529495584
# 0.49784274424170477
# 0.5444844023185815
# 0.5691081953448279
# 0.47376956338444215
# 0.5253041711927955
# 0.49945209529647727
# 0.5343353630989103
# 0.5179692375498358
# 0.5075826897022433
# 0.5152908264023035
# 0.5294118624925924
# 0.5044222378213088
# 0.5047263232272462
# 0.47572998425066343
# 0.5186929381769322
# 0.524428778608374
# 0.492480310813562
# 0.5266540923437465
# 0.5291491416271373
# 0.5311226347253881
# 0.4708877651008268
# 0.501774434121659
# 0.4979996583084945
# 0.47587133351785477
# 0.4765320574820784
# 0.4892115109892202
# 0.48562390376631426
# 0.5441663725521417
# 0.554468901783571
# 0.46285271397616545
# 0.5468106826840722
# 0.5257532725913151
# 0.5530896074641323
# 0.509875688539366
# 0.5273245859649215
# 0.5082949575208291
# 0.4444241534011297
# 0.5496784165231658
# 0.5529083542411599
# 0.5165247201116512
# -----
# 0.5073131673779194
# 0.5912567701190018 0.4444241534011297

# %%
beta = 0.4; peps = 4.6
def g(z):
    return 1

def b(k):
    return (math.exp(beta)/(math.exp(beta)-1))*(math.exp(beta*k)-1)

def S(k):
    return (1/2)*(1-(1/math.exp((peps-beta)*k)))

def ComputeZ(d):
    c = random.uniform(-0.5,0.5)
    #print(c)
    k = 0
    while(1):
        if S(k) <= math.fabs(c) and math.fabs(c) < S(k+1):
            break
        else:
            k += 1
    a = ((math.exp(peps-beta)-1)/(2*math.exp(peps-beta)))*(1/quad(lambda z: g(z),0,math.exp(beta))[0])
    fun = lambda x: math.fabs(math.fabs(c)-S(k)-(1/exp((peps-beta)*k))*quad(lambda z: a*g(z),0,x[0]/math.exp(beta*k))[0])
    bnds = ((0,math.exp(beta*(k+1))), (0,None))
    res = minimize(fun, (math.exp(beta*k),1), bounds = bnds)
    #print(res.fun, res.x)
    return (b(k)+res.x[0])*(c/math.fabs(c))

# %%
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(1)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 0.7407980971976815
# 0.8316150499927033
# 0.729527936308659
# 0.7234207676907171
# 0.8418705581389091
# 0.7835271171799186
# 0.699910098994884
# 0.7486812120849298
# 0.7512314269321417
# 0.7154586098608007
# 0.7256892013297762
# 0.8286716687268947
# 0.7821511036667255
# 0.7621230101210495
# 0.8465571706874876
# 0.73582782836384
# 0.6703501655361502
# 0.7336611590740207
# 0.7386170202569258
# 0.8321613268560454
# 0.8411266783502276
# 0.7938626472285965
# 0.7536372292020388
# 0.7235508725323687
# 0.7664306552733048
# 0.8017079943628008
# 0.7882722860234054
# 0.7613019335300996
# 0.7024053933435921
# 0.784405831368426
# 0.8271550481917421
# 0.8102407637316499
# 0.6693089582894275
# 0.7068332964752613
# 0.7626505785115397
# 0.8023778863134169
# 0.6962074841120405
# 0.8152829042805894
# 0.8294506782524068
# 0.7590878404951114
# 0.7806768908963768
# 0.7781038488298558
# 0.8070835486561446
# 0.7058117263035919
# 0.7612007350027392
# 0.7916707789384193
# 0.8377503630136204
# 0.774272946687858
# 0.7269424909477337
# 2.0848635024992133
# 2.1308125123835957
# 1.7934472497713727
# 2.5006515889819654
# 2.2545425918277537
# 2.1866282105523456
# 2.2531377563712764
# 1.9559446191725132
# 2.7356300251494527
# 2.185003768185294
# 2.6996087964776687
# 1.980638958372609
# 2.422120947862884
# 2.1417009840033865
# 2.5854310642982488
# 2.051895643353531
# 3.436778845420499
# 1.9738841087888133
# 2.068868698760963
# -----
# 2.2665043018753788
# 3.436778845420499 1.7139569912072108

# %%
beta = 1.6; peps = 3.4
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(1)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 4.3196362734473706
# 32.43430542382863
# 5.0170437209988705
# 8.869735560921994
# 8.588948403652354
# 8.835547489389887
# 7.904568854142274
# 5.6502264671103966
# 7.141361296229626
# 6.176799234137359
# 5.645970611508542
# 6.290938008720158
# 7.023716143277102
# 7.919871144254102
# 74.10212862969647
# 5.73080555607496
# 23.722718782583
# 9.330996437969041
# 5.941309468284123
# 8.737382668025871
# 4.246358343261856
# 6.928884226665497
# 8.793358985988007
# 17.0728321563693
# 18.09967270636501
# 4.612914746441761
# 5.385516404431035
# 14.69356941860876
# 5.606292254797177
# 6.88098438436894
# 5.670455968942012
# 21.446003980138357
# 8.877771167986555
# 5.302062052232045
# 7.081676262904893
# 21.833849807639325
# 9.062797815294187
# 22.046243865190064
# 6.136036182604882
# 6.993670313766277
# 9.15890827133182
# 3.7114891888245154
# 5.294936868724895
# 5.879678873951458
# 6.5903175299758425
# 10.44863066887408
# 6.74584851687616
# 5.034957724505797
# 9.926679848207161
# 4.578720648178529
# 96.22389998854096
# 12.983802897838153
# 6.06378701183857
# 6.228883866064523
# 5.822191528691418
# 5.515208946728264
# 4.966674815181953
# 7.047475319394998
# 5.294192758671333
# 6.220874460594903
# 9.092135381850053
# 7.405139000115951
# 9.343528696734463
# 9.046970759659622
# 21.369701226018016
# 5.727238580054511
# 7.841542893208117
# 7.332092947562277
# 12.642629377567387
# 8.744783673469474
# 7.021496057884967
# 11.17227614256129
# 9.140841315847576
# 6.9154101706756865
# 6.734475875588637
# 10.600070709820898
# 7.697625291134927
# 8.267966569696918
# 5.008821852555984
# 8.672028931043819
# 10.422143587728629
# 5.143047695771019
# 7.262819421992756
# 10.10352642876086
# 10.921235546332433
# 6.253549328977266
# 20.57441636082242
# 10.456973190147902
# 7.8149155997671675
# 11.621092294929248
# 5.804664937556438
# 74.33639549964738
# 8.545428263823824
# 9.684659379696207
# 6.4620759656386735
# 8.668486252126577
# 5.619361603622994
# 7.40004022360181
# 5.895072158983561
# 5.663528079273441
# -----
# 10.983223282234944
# 96.22389998854096 3.7114891888245154
