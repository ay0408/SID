# %%
from sympy import *
from scipy.optimize import minimize
from scipy import integrate
from scipy.integrate import quad
import matplotlib.pyplot as plt
import numpy as np
import math
import random

# %%
#beta = 0
def g(z):
    return -((math.exp(5)-1)/(math.exp(5)*math.log(2)))*math.log(z**0.17403545+1)+1

def b(k):
    return k

def S(k):
    return (1/2)*(1-(1/math.exp(5*k)))

def ComputeZ(d):
    c = random.uniform(-0.5,0.5)
    #print(c)
    k = 0
    while(1):
        if S(k) <= math.fabs(c) and math.fabs(c) < S(k+1):
            break
        else:
            k += 1
    a = ((math.exp(5)-1)/(2*math.exp(5)))*(1/quad(lambda z: g(z),0,1)[0])
    fun = lambda x: math.fabs(math.fabs(c)-S(k)-(1/exp(5*k))*quad(lambda z: a*g(z),0,x[0])[0])
    bnds = ((0,1), (0,None))
    res = minimize(fun, (0.5,1), bounds = bnds)
    #print(res.fun, res.x)
    return (b(k)+res.x[0])*(c/math.fabs(c))

# %%
def Evaluation(d):
    Z = 0
    for i in range(100):
        Z += math.fabs(ComputeZ(d))
    return Z/100

# %%
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(1)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 0.25567076787321996
# 0.2386216070597861
# 0.27494069372261604
# 0.31988158426389846
# 0.29483257881039493
# 0.2880638539414945
# 0.25845621817951914
# 0.2886779566701118
# 0.31925583150130366
# 0.2935051612553099
# 0.23354525685871014
# 0.2877155873505575
# 0.24926037412003932
# 0.2633116829716047
# 0.28303690345943666
# 0.28609391362544206
# 0.29909487345227304
# 0.27465757388206363
# 0.25977924823124054
# 0.28113206452837247
# 0.2739618863032466
# 0.2982472846414619
# 0.2619540847527352
# 0.2751705290428675
# 0.32668871297494306
# 0.3160958069289097
# 0.2701478674528241
# 0.34099503317708907
# 0.2936610273150823
# 0.278377226870737
# 0.28307090051988204
# 0.25414487468301966
# 0.3040399526643679
# 0.2687531640659654
# 0.2439508364724254
# 0.25491953081638774
# 0.2804188157024179
# 0.25994215905300333
# 0.2632992550640981
# 0.2875261945056327
# 0.3090486522969657
# 0.3035578995294067
# 0.2413232347988639
# 0.24503558200563283
# 0.24487624954536036
# 0.32356178451407497
# 0.2622231279013445
# 0.24531775822716245
# 0.2861530570413846
# 0.25132300480039005
# 0.26751693847309616
# 0.25257194781222975
# 0.27148247134078657
# 0.27147715977136344
# 0.27835183376486206
# 0.3354640900491428
# 0.2957638157503716
# 0.32424863460798853
# 0.2801394767457911
# 0.290945142828716
# 0.2415039229767482
# 0.27311397467072296
# 0.299717341081754
# 0.28258678540869914
# 0.2492417578431349
# 0.261429374676398
# 0.28102469529485363
# 0.282252916768776
# 0.28191752386311314
# 0.2922107201781981
# 0.2611677614667231
# 0.30373933444247353
# 0.2658473867442521
# 0.2876035777551948
# 0.2981065830220851
# 0.29877065178334755
# 0.2545718752136178
# 0.29102816402707515
# 0.25969406536066814
# 0.27628134068973315
# 0.29383163690195707
# 0.28035640705157466
# 0.26306953571545605
# 0.2656627425261562
# 0.30978291958115745
# 0.26840608940800265
# 0.2691612227961041
# 0.27239420102437634
# 0.27525001628170953
# 0.2599015750920876
# 0.2469466249198387
# 0.286647168713572
# 0.3061582474974998
# 0.21492738550649995
# 0.2686055491906711
# 0.29075369781102817
# 0.2735503148540793
# 0.2709073026979249
# 0.2936273499109569
# 0.2733791541542512
# -----
# 0.2779040963147189
# 0.34099503317708907 0.21492738550649995

# %%
beta = 0.4; peps = 5; r = 0.17921531
def g(z):
    return -((math.exp(peps)-1)/(math.exp(peps)*math.log(math.exp(beta*r)+1)))*math.log(z**r+1)+1

def b(k):
    return (math.exp(beta)/(math.exp(beta)-1))*(math.exp(beta*k)-1)

def S(k):
    return (1/2)*(1-(1/math.exp((peps-beta)*k)))

def ComputeZ(d):
    c = random.uniform(-0.5,0.5)
    #print(c)
    k = 0
    while(1):
        if S(k) <= math.fabs(c) and math.fabs(c) < S(k+1):
            break
        else:
            k += 1
    a = ((math.exp(peps-beta)-1)/(2*math.exp(peps-beta)))*(1/quad(lambda z: g(z),0,math.exp(beta))[0])
    fun = lambda x: math.fabs(math.fabs(c)-S(k)-(1/exp((peps-beta)*k))*quad(lambda z: a*g(z),0,x[0]/math.exp(beta*k))[0])
    bnds = ((0,math.exp(beta*(k+1))), (0,None))
    res = minimize(fun, (math.exp(beta*k),1), bounds = bnds)
    #print(res.fun, res.x)
    return (b(k)+res.x[0])*(c/math.fabs(c))

# %%
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(1)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 0.42248115691547333
# 0.4555542108454955
# 0.37616485708790603
# 0.4322303531238494
# 0.4159566421177194
# 0.44482741940763354
# 0.40392081292959586
# 0.3505183995174457
# 0.46685653995040693
# 0.41329738733894217
# 0.42151589425223185
# 0.42185113216636616
# 0.5109056826606413
# 0.4622989321080848
# 0.3834294054060001
# 0.4116386812699621
# 0.41049949042494893
# 0.5000326267604301
# 0.37259579193272335
# 0.44227397440352384
# 0.4787585747574344
# 0.4065797124927462
# 0.47765436603339945
# 0.4164073679644896
# 0.48239449676255464
# 0.4032178438504273
# 0.439626408781744
# 0.3995085129841315
# 0.4223290526144682
# 0.3971565322352755
# 0.45989079562562873
# 0.3710098110190226
# 0.4092868824721944
# 0.45641946779625137
# 0.3892141539285644
# 0.43431760317916845
# 0.3683283869390606
# 0.5218427231622945
# 0.46218145016331463
# 0.4377696437358439
# 0.4942888421771075
# 0.4956653595864029
# 0.4047422784886157
# 0.47381570459615874
# 0.3981227826773096
# 0.48981032577824685
# 0.41671252095656236
# 0.6018229448627009
# 0.5889575397508803
# 0.6957407942201592
# 0.6342312109799965
# 0.6730152045934956
# 0.6824209684274456
# 0.6756066637861852
# 0.6341838312365636
# 0.5849181820250089
# 0.671897162793833
# 0.7307375912623203
# 0.7314330993102743
# 0.6381492097427857
# 0.7916012978682943
# 0.6396625052910305
# 0.6891424390038359
# 0.6497695193722167
# 0.6664482998023799
# 0.7079532642257981
# 0.6934888768656968
# 0.5840322520285874
# 0.6342784612183804
# 0.6381923706404647
# 0.6583260009980468
# 0.745017625266037
# 0.6120418331860757
# 0.7554589107000297
# 0.5987134705403413
# 0.6308736642046981
# 0.5912735323136752
# 0.7475373194646369
# 0.5734129553476406
# 0.6763496361234647
# 0.6766290571346567
# 0.59342279119207
# -----
# 0.658831608564309
# 0.8078161408787288 0.4700724537274457

# %%
beta = 1.2; peps = 5; r = 0.19057043
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(1)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 0.9893138684281746
# 0.9589218376316458
# 0.8874297257089019
# 1.029828709171688
# 1.1822531435366364
# 0.8263355052990851
# 1.1669040491228289
# 0.8346435114474439
# 1.0780369023397163
# 1.1022030811021186
# 1.0105172132083255
# 1.0191865097054091
# 0.8802033208438886
# 1.0066648840578822
# 1.004007672869147
# 1.26644448154384
# 1.0591251352650106
# 1.0053470303370409
# 0.8668151089161027
# 1.2158511020898373
# 0.953489304293782
# 1.1202997597477315
# 0.9151295924544115
# 0.939835339697563
# 1.028049711361063
# 1.2331886289049363
# 1.1026763489963118
# 1.051645043409763
# 1.0312648961123705
# 1.1211435517075246
# 1.1119442553794332
# 1.1761293057557578
# 0.8281274967056527
# 1.0885715967191023
# 1.030795583130251
# 1.1518262536430113
# 0.934847280812654
# 0.9822333774198847
# 1.1462661908646024
# 1.115896841168348
# 1.0186859977803677
# 1.0328460094924083
# 0.8700324332840208
# 0.9237570487492148
# 1.1364152831594676
# 0.9685773734604188
# 1.0490970716050088
# 1.1563655273430258
# 1.004376742203333
# 0.8424270519760316
# 1.0087501301313497
# 1.0274522142849651
# 1.1154879176919714
# 1.0579759944779517
# 1.1111813695657184
# 0.9051305730919715
# 1.2258656356798312
# 1.1150623595927847
# 1.1424556159274863
# 1.2760924973149392
# 1.3737857698257394
# 1.1086405214297965
# 1.0146162057322583
# 0.8932883780073407
# 1.0248017227103594
# 1.1161123435938607
# 0.9256833322727993
# 1.0242123283642233
# 1.1280667567350413
# 0.9341177667082446
# 1.1541846015794892
# 1.0064444762266425
# 1.0242477407100288
# 1.1239087939521468
# 1.3232108760958878
# 0.9800393923511395
# 0.9370422253337338
# 0.9466639508221801
# 1.119037596586898
# 0.8858763198879328
# 1.0765217552184496
# 1.1309865839526936
# 1.2197089359375437
# 0.943933261880051
# 1.053500248660619
# 0.9870254008473052
# 0.890275188292025
# 0.885902664701691
# 0.9387568657522597
# 1.0863519931041081
# 1.2324681190013467
# 0.9526099621191285
# 1.102343493523155
# 0.9439757425581432
# 1.3233430232658594
# 1.1390970926106692
# 0.8975662292976756
# 1.1188400017307463
# 0.9627888386477488
# 1.2770050857452795
# -----
# 1.0464840958349337
# 1.3737857698257394 0.8263355052990851

# %%
beta = 1.6; peps = 5; r = 0.19823616
ave = 0; M = 0; m = 10000000
for i in range(100):
    Z = Evaluation(1)
    M = max(Z,M); m = min(Z,m)
    print(Z)
    ave += Z
    
print("-----")
print(ave/100)
print(M, m)
# Out:
# 1.5999820296171392
# 2.1892017706760174
# 1.746486432987165
# 1.8120263320257093
# 1.4507466638049473
# 1.2709765124090173
# 1.6936309471441948
# 1.5155018601651573
# 1.6932216945120195
# 1.526866840797342
# 1.3835046401104076
# 1.6447869266393302
# 1.5505661133151523
# 1.5959020039844216
# 1.4253763814995781
# 1.50309772003607
# 1.6193383558211532
# 1.6599421928815747
# 1.7697852153954303
# 2.2143055552328086
# 1.431278020479228
# 2.0137948819265814
# 1.4884425396620489
# 1.4096559498149037
# 1.8027371263061938
# 2.170906170505961
# 2.2372617290575336
# 1.660865967987246
# 1.6365758248531563
# 1.3954126005674203
# 1.2869721138828427
# 2.2956687525543833
# 1.931176432916679
# 1.7587038839724185
# 2.0727239250660205
# 2.156786683722405
# 1.5635737775400644
# 1.4732524781728324
# 1.571962302464054
# 2.09399463398922
# 1.3939894631271743
# 1.5935038962767802
# 1.9391592044555461
# 1.5310474791633562
# 1.5802487128524252
# 1.7414512901347856
# 1.4460179871901153
# 1.4078128476203742
# 1.4697938500985572
# 1.6284724013944043
# 1.6020003354078773
# 1.8306100733638349
# 1.5656614118003784
# 2.0731879540355767
# 2.0404073266421334
# 2.0238661043476696
# 1.707452587962118
# 1.7857806144568311
# 1.3523438318704746
# 1.2514424577855738
# 1.7190813504772344
# 2.183855923152755
# 1.5767428117667706
# 1.7589956204815829
# 1.7795463359108592
# 1.4508380149539337
# 1.595019762696818
# 1.7421519323559922
# 1.842192644036485
# 1.4590883285542975
# 2.071503273718586
# 1.9776627830919724
# 1.3139941031997033
# 1.872720507576732
# 1.950728868345933
# 1.5829634672271005
# 1.8571663044457967
# 1.463788608871057
# 1.8118958439290733
# 2.132474460911403
# 1.3557071157043492
# 2.184125436246592
# 1.1025338731659102
# 2.215114800068968
# 1.4557804657930995
# 2.1606217865757924
# 1.3239636264949086
# 1.6116099510173845
# 1.605019594178105
# 2.023868897586595
# 2.173091478526585
# 1.6593785502953855
# 2.134549344077612
# 1.4927890564998378
# 1.5542836884530429
# 1.4661096668172644
# 1.7836810741757907
# 1.6336265216408319
# 2.0965940830178
# 1.8196549015460581
# -----
# 1.7127575667206782
# 2.2956687525543833 1.1025338731659102
