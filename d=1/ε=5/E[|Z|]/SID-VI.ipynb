# %%
from sympy import *
from scipy.optimize import minimize
from scipy import integrate
from scipy.integrate import quad

# %%
def E(peps,beta):
    return 1/(exp(peps-2*beta)-1) + ((exp(peps-beta)-1)/(exp(peps-2*beta)-1))*(1/2)

def a(peps,beta):
    return peps

# %%
eps = 5; beta = 0

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.506783654906304 [5. 0.]

# %%
beta = 0.2

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.624507337890866 [4.8 0. ]

# %%
beta = 0.4

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.774422156123721 [4.6 0. ]

# %%
beta = 0.6

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.971021477726917 [4.4 0. ]

# %%
beta = 0.8

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 1.24216747658050 [4.2 0. ]

# %%
beta = 1.0

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 1.65012926766419 [4. 0.]

# %%
beta = 1.2

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 2.36706896307338 [3.8 0. ]

# %%
beta = 1.4

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 4.09003618988304 [3.6 0. ]

# %%
beta = 1.6

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 15.9204147296869 [3.4 0. ]

# %%
beta = 1.8

fun = lambda x: E(x[0],beta) 
bnds = ((0,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta,0), bounds = bnds, constraints = cons)
print(res.fun, res.x)
# Out:
# nan [3.6 0. ]
