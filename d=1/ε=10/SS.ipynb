# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
def SS1(eps,beta):
    k = 2-(6*beta)/eps
    alpha = (eps/(2*(3**(3/4))))*k
    return 1/(alpha*(2**(1/2)))

def SS2(eps,beta):
    k = 2-(6*beta)/eps
    alpha = (eps/4)*k
    return (1/alpha)*(2/(math.pi))

def SS3(eps,beta):
    k = 2-(10*beta)/eps
    alpha = (eps/(2*(5**(5/6))))*k
    return 1/(alpha*(3**(1/2)))

# %%
beta = [0.4*i for i in range(12)]

# %%
eps = 10
for i in range(9):
    print(SS1(eps,beta[i]))
# Out:
# 0.16118548977353125
# 0.1831653292881037
# 0.2120861707546464
# 0.2518523277711426
# 0.3099720957183294
# 0.40296372443382816
# 0.5756624634768975
# 1.0074093110845708
# 4.0296372443383

# %%
for i in range(9):
    print(SS2(eps,beta[i]))
# Out:
# 0.12732395447351627
# 0.14468631190172304
# 0.16753151904410035
# 0.19894367886486922
# 0.24485375860291597
# 0.3183098861837907
# 0.45472840883398685
# 0.7957747154594772
# 3.1830988618379217

# %%
for i in range(5):
    print(SS3(eps,beta[i]))
# Out:
# 0.220756945463137
# 0.2759461818289212
# 0.36792824243856165
# 0.5518923636578426
# 1.103784727315685
