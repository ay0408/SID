# %%
from sympy import *
from scipy.optimize import minimize
from scipy import integrate
from scipy.integrate import quad

# %%
def E(peps,beta):
    return 1/(exp(peps-2*beta)-1) + ((exp(peps-beta)-1)/(exp(peps-2*beta)-1))*(1/2)

def a(peps,beta):
    return peps

# %%
eps = 10; beta = 0

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.500045401991010 [10.  0.]

# %%
beta = 0.4

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.746100177332242 [9.6 0. ]

# %%
beta = 0.8

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 1.11357798166012 [9.2 0. ]

# %%
beta = 1.2

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 1.66365349557047 [8.8 0. ]

# %%
beta = 1.6

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 2.49302744088832 [8.4 0. ]

# %%
beta = 2.0

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 3.77278687084016 [8. 0.]

# %%
beta = 2.4

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 5.90082261435248 [7.6 0. ]

# %%
beta = 2.8

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 10.4288125941168 [7.2 0. ]

# %%
beta = 3.2

fun = lambda x: E(x[0],beta) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-a(x[0],beta)},)
res = minimize(fun, (2*beta+1,0), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 38.2232069922420 [6.8 0. ]
