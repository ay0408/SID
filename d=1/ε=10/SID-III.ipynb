# %%
from sympy import *
from scipy.optimize import minimize
from scipy import integrate
from scipy.integrate import quad

# %%
def E(peps,beta,r):
    c,e = quad(lambda z: z*(1/((exp(peps)-1)*(z**r)+exp(beta*r))),0,exp(beta))
    m,e = quad(lambda z: 1/((exp(peps)-1)*(z**r)+exp(beta*r)),0,exp(beta))
    return 1/(exp(peps-2*beta)-1) + ((exp(peps-beta)-1)/(exp(peps-2*beta)-1))*(1/exp(beta))*(c/m)

def g(z,beta,peps,r):
    return 1/((exp(peps)-1)*(z**r)+exp(beta*r))

def S(peps,beta,r):
    fun1 = lambda z: -g(z[0],beta,peps,r)/g(z[0]+1,beta,peps,r)
    bnds1 = ((0,exp(beta)-1), (0,None))
    res1 = minimize(fun1, (0,0), bounds = bnds1)
    #print(log(-res1.fun).evalf())
    fun2 = lambda z: -exp(peps)*g(z[0],beta,peps,r)/g((z[0]+1-exp(beta))/exp(beta),beta,peps,r)
    bnds2 = ((exp(beta)-0.999,exp(beta)), (0,None))
    res2 = minimize(fun2, (exp(beta)-1, 0), bounds = bnds2)
    #print(log(-res2.fun).evalf())
    x = max(-res1.fun, -res2.fun)
    return log(x)

# %%
eps = 10; beta = 0
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.0215587563263530 [10.          1.96103403]

# %%
beta = 0.4
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.0321960469464750 [10.          1.96529065]

# %%
beta = 0.8
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.0481094857184410 [10.          1.96191332]

# %%
beta = 1.2
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.0719519249400883 [10.          1.96421661]

# %%
beta = 1.6
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.107765263185192 [10.        1.963636]

# %%
beta = 2.0
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.161788470577619 [10.          1.96363974]

# %%
beta = 2.4
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.243886728787350 [10.          1.96401135]

# %%
beta = 2.8
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.370336381988348 [10.          1.96403372]

# %%
beta = 3.2
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.570085152151731 [10.          1.96400836]

# %%
beta = 3.6
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 0.901676896558554 [10.          1.96358892]

# %%
beta = 4.0
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 1.51157233001037 [10.          1.96455444]

# %%
beta = 4.4
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 2.92925543008529 [10.          1.96397262]

# %%
beta = 4.8
#peps = x[0], r = x[1]

fun = lambda x: E(x[0],beta,x[1]) 
bnds = ((2*beta,eps), (0,None))
cons = ({'type': 'ineq', 'fun': lambda x:  eps-beta-S(x[0],beta,x[1])},)
res = minimize(fun, (2*beta+1,1), bounds = bnds, constraints = cons)
print(res.fun.evalf(), res.x)
# Out:
# 9.91862903806770 [10.          1.96404839]
